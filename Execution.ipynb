# %% [markdown]
# Import modules and check that version is correct.

# %%
import tensorflow as tf
import onnxruntime as ort
print("runtime", ort.__version__)
import onnx
print("onnx", onnx.__version__)
import onnxsim 
print("simplifier", onnxsim.__version__)
import onnx_graphsurgeon
print("surgeon", onnx_graphsurgeon.__version__)
import simple_onnx_processing_tools
print("processing tools",simple_onnx_processing_tools.__version__)
import tensorflow as tf
print("tensorflow",tf.__version__)
import tf_keras
print("tfkeras",tf_keras.__version__)
import ai_edge_litert
print("ai", ai_edge_litert.__version__)
import psutil
print("psutil", psutil.__version__)
import ml_dtypes
print("ml_dtypes", ml_dtypes.__version__)
import flatbuffers
print("flat", flatbuffers.__version__)
import onnx2tf

# %% [markdown]
# Import onnx model and convert it into tensorflow using the onnx2tf module

# %%
model_path="/Users/omaralmutoteh/NeuralHash/model.onnx"
tf_model=onnx2tf.convert(input_onnx_file_path=model_path)
# Out:
# Model optimizing started ============================================================
# Traceback (most recent call last):
#   File "/Users/omaralmutoteh/anaconda3/envs/NeuralHash/lib/python3.11/site-packages/onnx2tf/onnx2tf.py", line 652, in convert
#     result = subprocess.check_output(
#              ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/omaralmutoteh/anaconda3/envs/NeuralHash/lib/python3.11/subprocess.py", line 466, in check_output
#     return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/omaralmutoteh/anaconda3/envs/NeuralHash/lib/python3.11/subprocess.py", line 548, in run
#     with Popen(*popenargs, **kwargs) as process:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/omaralmutoteh/anaconda3/envs/NeuralHash/lib/python3.11/subprocess.py", line 1026, in __init__
#     self._execute_child(args, executable, preexec_fn, close_fds,
#   File "/Users/omaralmutoteh/anaconda3/envs/NeuralHash/lib/python3.11/subprocess.py", line 1955, in _execute_child
#     raise child_exception_type(errno_num, err_msg, err_filename)
# FileNotFoundError: [Errno 2] No such file or directory: 'onnxsim'
#
# WARNING: Failed to optimize the onnx file.
#
# Automatic generation of each OP name started ========================================
# Automatic generation of each OP name complete!
#
# Model loaded ========================================================================
#
# Model conversion started ============================================================
# INFO: input_op_name: image shape: [1, 3, 360, 360] dtype: float32
#
# INFO: 2 / 236
# INFO: onnx_op_type: Conv onnx_op_name: sng_Conv_0
# INFO:  input_name.1: image shape: [1, 3, 360, 360] dtype: float32
# INFO:  input_name.2: 1 shape: [16, 3, 3, 3] dtype: float32
# INFO:  output_name.1: stem/MobilenetV3/Conv2d_0/Conv2D shape: [1, 16, 180, 180] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: image shape: (1, 360, 360, 3) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (3, 3, 3, 16) dtype: <dtype: 'float32'>
# INFO:  input.3.bias:
# INFO:  input.4.strides: val: [2, 2]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: SAME
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.nn.convolution/convolution:0 shape: (1, 180, 180, 16) dtype: <dtype: 'float32'>
#
# INFO: 3 / 236
# INFO: onnx_op_type: InstanceNormalization onnx_op_name: sng_InstanceNormalization_1
# INFO:  input_name.1: stem/MobilenetV3/Conv2d_0/Conv2D shape: [1, 16, 180, 180] dtype: float32
# INFO:  input_name.2: 3s shape: [16] dtype: float32
# INFO:  input_name.3: 3bias shape: [16] dtype: float32
# INFO:  output_name.1: stem/MobilenetV3/Conv2d_0/InstanceNorm/instancenorm/add_1 shape: [1, 16, 180, 180] dtype: float32
# INFO: tf_op_type: InstanceNormalization
# INFO:  input.1.x: name: tf.compat.v1.transpose/transpose:0 shape: (1, 180, 180, 16) dtype: <dtype: 'float32'>
# INFO:  input.2.mean: name: tf.math.reduce_mean_2/Mean:0 shape: (1, 1, 1, 16) dtype: <dtype: 'float32'>
# INFO:  input.3.variance: name: tf.math.reduce_mean_3/Mean:0 shape: (1, 1, 1, 16) dtype: <dtype: 'float32'>
# INFO:  input.4.offset: shape: (16,) dtype: <dtype: 'float32'>
# INFO:  input.5.scale: shape: (16,) dtype: <dtype: 'float32'>
# INFO:  input.6.variance_epsilon: shape: () dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.__operators__.add_3/AddV2:0 shape: (1, 180, 180, 16) dtype: <dtype: 'float32'>
#
# INFO: 4 / 236
# INFO: onnx_op_type: Add onnx_op_name: sng_Add_2
# INFO:  input_name.1: stem/MobilenetV3/Conv2d_0/InstanceNorm/instancenorm/add_1 shape: [1, 16, 180, 180] dtype: float32
# INFO:  input_name.2: elementwise_stem/MobilenetV3/Conv2d_0/add shape: [1] dtype: float32
# INFO:  output_name.1: stem/MobilenetV3/Conv2d_0/add shape: [1, 16, 180, 180] dtype: float32
# INFO: tf_op_type: add
# INFO:  input.1.x: name: tf.__operators__.add_3/AddV2:0 shape: (1, 180, 180, 16) dtype: <dtype: 'float32'>
# INFO:  input.2.y: shape: (1, 1, 1, 1) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.add_1/Add:0 shape: (1, 180, 180, 16) dtype: <dtype: 'float32'>
#
# INFO: 5 / 236
# INFO: onnx_op_type: Clip onnx_op_name: sng_Clip_3
# INFO:  input_name.1: stem/MobilenetV3/Conv2d_0/add shape: [1, 16, 180, 180] dtype: float32
# INFO:  input_name.2: elementwise_stem/MobilenetV3/Conv2d_0/Relu6alpha shape: [1] dtype: float32
# INFO:  input_name.3: elementwise_stem/MobilenetV3/Conv2d_0/Relu6beta shape: [1] dtype: float32
# INFO:  output_name.1: stem/MobilenetV3/Conv2d_0/Relu6 shape: [1, 16, 180, 180] dtype: float32
# INFO: tf_op_type: relu6
# INFO:  input.1.features: name: tf.math.add_1/Add:0 shape: (1, 180, 180, 16) dtype: <dtype: 'float32'>
# INFO:  input.2.min_value: shape: (1,) dtype: float32
# INFO:  input.3.max_value: shape: (1,) dtype: float32
# INFO:  output.1.output: name: tf.nn.relu6/Relu6:0 shape: (1, 180, 180, 16) dtype: <dtype: 'float32'>
#
# INFO: 6 / 236
# INFO: onnx_op_type: Mul onnx_op_name: sng_Mul_4
# INFO:  input_name.1: stem/MobilenetV3/Conv2d_0/Relu6 shape: [1, 16, 180, 180] dtype: float32
# INFO:  input_name.2: elementwise_stem/MobilenetV3/Conv2d_0/mul shape: [1] dtype: float32
# INFO:  output_name.1: stem/MobilenetV3/Conv2d_0/mul shape: [1, 16, 180, 180] dtype: float32
# INFO: tf_op_type: multiply
# INFO:  input.1.x: name: tf.nn.relu6/Relu6:0 shape: (1, 180, 180, 16) dtype: <dtype: 'float32'>
# INFO:  input.2.y: shape: (1, 1, 1, 1) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.multiply_5/Mul:0 shape: (1, 180, 180, 16) dtype: <dtype: 'float32'>
#
# INFO: 7 / 236
# INFO: onnx_op_type: Mul onnx_op_name: sng_Mul_5
# INFO:  input_name.1: stem/MobilenetV3/Conv2d_0/InstanceNorm/instancenorm/add_1 shape: [1, 16, 180, 180] dtype: float32
# INFO:  input_name.2: stem/MobilenetV3/Conv2d_0/mul shape: [1, 16, 180, 180] dtype: float32
# INFO:  output_name.1: stem/MobilenetV3/Conv2d_0/mul_1 shape: [1, 16, 180, 180] dtype: float32
# INFO: tf_op_type: multiply
# INFO:  input.1.x: name: tf.__operators__.add_3/AddV2:0 shape: (1, 180, 180, 16) dtype: <dtype: 'float32'>
# INFO:  input.2.y: name: tf.math.multiply_5/Mul:0 shape: (1, 180, 180, 16) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.multiply_9/Mul:0 shape: (1, 180, 180, 16) dtype: <dtype: 'float32'>
#
# INFO: 8 / 236
# INFO: onnx_op_type: Conv onnx_op_name: sng_Conv_6
# INFO:  input_name.1: stem/MobilenetV3/Conv2d_0/mul_1 shape: [1, 16, 180, 180] dtype: float32
# INFO:  input_name.2: 5 shape: [16, 16, 1, 1] dtype: float32
# INFO:  output_name.1: stem/MobilenetV3/Bottleneck_1/expand/Conv2D shape: [1, 16, 180, 180] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.math.multiply_9/Mul:0 shape: (1, 180, 180, 16) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (1, 1, 16, 16) dtype: <dtype: 'float32'>
# INFO:  input.3.bias:
# INFO:  input.4.strides: val: [1, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: SAME
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.nn.convolution_1/convolution:0 shape: (1, 180, 180, 16) dtype: <dtype: 'float32'>
#
# INFO: 9 / 236
# INFO: onnx_op_type: InstanceNormalization onnx_op_name: sng_InstanceNormalization_7
# INFO:  input_name.1: stem/MobilenetV3/Bottleneck_1/expand/Conv2D shape: [1, 16, 180, 180] dtype: float32
# INFO:  input_name.2: 7s shape: [16] dtype: float32
# INFO:  input_name.3: 7bias shape: [16] dtype: float32
# INFO:  output_name.1: stem/MobilenetV3/Bottleneck_1/expand/InstanceNorm/instancenorm/add_1 shape: [1, 16, 180, 180] dtype: float32
# INFO: tf_op_type: InstanceNormalization
# INFO:  input.1.x: name: tf.compat.v1.transpose_2/transpose:0 shape: (1, 180, 180, 16) dtype: <dtype: 'float32'>
# INFO:  input.2.mean: name: tf.math.reduce_mean_6/Mean:0 shape: (1, 1, 1, 16) dtype: <dtype: 'float32'>
# INFO:  input.3.variance: name: tf.math.reduce_mean_7/Mean:0 shape: (1, 1, 1, 16) dtype: <dtype: 'float32'>
# INFO:  input.4.offset: shape: (16,) dtype: <dtype: 'float32'>
# INFO:  input.5.scale: shape: (16,) dtype: <dtype: 'float32'>
# INFO:  input.6.variance_epsilon: shape: () dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.__operators__.add_7/AddV2:0 shape: (1, 180, 180, 16) dtype: <dtype: 'float32'>
#
# INFO: 10 / 236
# INFO: onnx_op_type: Relu onnx_op_name: sng_Relu_8
# INFO:  input_name.1: stem/MobilenetV3/Bottleneck_1/expand/InstanceNorm/instancenorm/add_1 shape: [1, 16, 180, 180] dtype: float32
# INFO:  output_name.1: stem/MobilenetV3/Bottleneck_1/expand/Relu shape: [1, 16, 180, 180] dtype: float32
# INFO: tf_op_type: relu
# INFO:  input.1.features: name: tf.__operators__.add_7/AddV2:0 shape: (1, 180, 180, 16) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.nn.relu/Relu:0 shape: (1, 180, 180, 16) dtype: <dtype: 'float32'>
#
# INFO: 11 / 236
# INFO: onnx_op_type: Conv onnx_op_name: sng_Conv_9
# INFO:  input_name.1: stem/MobilenetV3/Bottleneck_1/expand/Relu shape: [1, 16, 180, 180] dtype: float32
# INFO:  input_name.2: 9 shape: [16, 1, 3, 3] dtype: float32
# INFO:  output_name.1: stem/MobilenetV3/Bottleneck_1/depthwise/depthwise shape: [1, 16, 90, 90] dtype: float32
# INFO: tf_op_type: depthwise_conv2d_v2
# INFO:  input.1.input: name: tf.nn.relu/Relu:0 shape: (1, 180, 180, 16) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (3, 3, 16, 1) dtype: <dtype: 'float32'>
# INFO:  input.3.bias:
# INFO:  input.4.strides: val: [1, 2, 2, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: SAME
# INFO:  input.7.group: val: 16
# INFO:  output.1.output: name: tf.compat.v1.nn.depthwise_conv2d/depthwise:0 shape: (1, 90, 90, 16) dtype: <dtype: 'float32'>
#
# INFO: 12 / 236
# INFO: onnx_op_type: InstanceNormalization onnx_op_name: sng_InstanceNormalization_10
# INFO:  input_name.1: stem/MobilenetV3/Bottleneck_1/depthwise/depthwise shape: [1, 16, 90, 90] dtype: float32
# INFO:  input_name.2: 11s shape: [16] dtype: float32
# INFO:  input_name.3: 11bias shape: [16] dtype: float32
# INFO:  output_name.1: stem/MobilenetV3/Bottleneck_1/depthwise/InstanceNorm/instancenorm/add_1 shape: [1, 16, 90, 90] dtype: float32
# INFO: tf_op_type: InstanceNormalization
# INFO:  input.1.x: name: tf.compat.v1.transpose_3/transpose:0 shape: (1, 90, 90, 16) dtype: <dtype: 'float32'>
# INFO:  input.2.mean: name: tf.math.reduce_mean_10/Mean:0 shape: (1, 1, 1, 16) dtype: <dtype: 'float32'>
# INFO:  input.3.variance: name: tf.math.reduce_mean_11/Mean:0 shape: (1, 1, 1, 16) dtype: <dtype: 'float32'>
# INFO:  input.4.offset: shape: (16,) dtype: <dtype: 'float32'>
# INFO:  input.5.scale: shape: (16,) dtype: <dtype: 'float32'>
# INFO:  input.6.variance_epsilon: shape: () dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.__operators__.add_11/AddV2:0 shape: (1, 90, 90, 16) dtype: <dtype: 'float32'>
#
# INFO: 13 / 236
# INFO: onnx_op_type: AveragePool onnx_op_name: sng_AveragePool_11
# INFO:  input_name.1: stem/MobilenetV3/Bottleneck_1/depthwise/InstanceNorm/instancenorm/add_1 shape: [1, 16, 90, 90] dtype: float32
# INFO:  output_name.1: stem/MobilenetV3/Bottleneck_1/gap/Mean shape: [1, 16, 1, 1] dtype: float32
# INFO: tf_op_type: AveragePooling2D
# INFO:  input.1.x: name: tf.__operators__.add_11/AddV2:0 shape: (1, 90, 90, 16) dtype: <dtype: 'float32'>
# INFO:  input.2.pool_size: val: [90, 90]
# INFO:  input.3.strides: val: [1, 1]
# INFO:  input.4.padding: val: [0, 0, 0, 0]
# INFO:  output.1.output: name: tf.compat.v1.nn.avg_pool/AvgPool:0 shape: (1, 1, 1, 16) dtype: <dtype: 'float32'>
#
# INFO: 14 / 236
# INFO: onnx_op_type: Conv onnx_op_name: sng_Conv_12
# INFO:  input_name.1: stem/MobilenetV3/Bottleneck_1/gap/Mean shape: [1, 16, 1, 1] dtype: float32
# INFO:  input_name.2: 15 shape: [4, 16, 1, 1] dtype: float32
# INFO:  input_name.3: 13 shape: [4] dtype: float32
# INFO:  output_name.1: conv_stem/MobilenetV3/Bottleneck_1/Bottleneck_1/Conv/Conv2D shape: [1, 4, 1, 1] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.compat.v1.nn.avg_pool/AvgPool:0 shape: (1, 1, 1, 16) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (1, 1, 16, 4) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (4,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [1, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: SAME
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.math.add_2/Add:0 shape: (1, 1, 1, 4) dtype: <dtype: 'float32'>
#
# INFO: 15 / 236
# INFO: onnx_op_type: Relu onnx_op_name: sng_Relu_13
# INFO:  input_name.1: conv_stem/MobilenetV3/Bottleneck_1/Bottleneck_1/Conv/Conv2D shape: [1, 4, 1, 1] dtype: float32
# INFO:  output_name.1: stem/MobilenetV3/Bottleneck_1/Bottleneck_1/Conv/Conv2D shape: [1, 4, 1, 1] dtype: float32
# INFO: tf_op_type: relu
# INFO:  input.1.features: name: tf.math.add_2/Add:0 shape: (1, 1, 1, 4) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.nn.relu_1/Relu:0 shape: (1, 1, 1, 4) dtype: <dtype: 'float32'>
#
# INFO: 16 / 236
# INFO: onnx_op_type: Conv onnx_op_name: sng_Conv_14
# INFO:  input_name.1: stem/MobilenetV3/Bottleneck_1/Bottleneck_1/Conv/Conv2D shape: [1, 4, 1, 1] dtype: float32
# INFO:  input_name.2: 19 shape: [16, 4, 1, 1] dtype: float32
# INFO:  input_name.3: 17 shape: [16] dtype: float32
# INFO:  output_name.1: stem/MobilenetV3/Bottleneck_1/Bottleneck_1_1/Conv_1/Conv2D shape: [1, 16, 1, 1] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.nn.relu_1/Relu:0 shape: (1, 1, 1, 4) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (1, 1, 4, 16) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (16,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [1, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: SAME
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.math.add_3/Add:0 shape: (1, 1, 1, 16) dtype: <dtype: 'float32'>
#
# INFO: 17 / 236
# INFO: onnx_op_type: Add onnx_op_name: sng_Add_15
# INFO:  input_name.1: stem/MobilenetV3/Bottleneck_1/Bottleneck_1_1/Conv_1/Conv2D shape: [1, 16, 1, 1] dtype: float32
# INFO:  input_name.2: elementwise_stem/MobilenetV3/Conv2d_0/add shape: (1,) dtype: float32
# INFO:  output_name.1: stem/MobilenetV3/Bottleneck_1/Bottleneck_1_1/Conv_1/add shape: [1, 16, 1, 1] dtype: float32
# INFO: tf_op_type: add
# INFO:  input.1.x: name: tf.math.add_3/Add:0 shape: (1, 1, 1, 16) dtype: <dtype: 'float32'>
# INFO:  input.2.y: shape: (1, 1, 1, 1) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.add_4/Add:0 shape: (1, 1, 1, 16) dtype: <dtype: 'float32'>
#
# INFO: 18 / 236
# INFO: onnx_op_type: Clip onnx_op_name: sng_Clip_16
# INFO:  input_name.1: stem/MobilenetV3/Bottleneck_1/Bottleneck_1_1/Conv_1/add shape: [1, 16, 1, 1] dtype: float32
# INFO:  input_name.2: elementwise_stem/MobilenetV3/Conv2d_0/Relu6alpha shape: (1,) dtype: float32
# INFO:  input_name.3: elementwise_stem/MobilenetV3/Conv2d_0/Relu6beta shape: (1,) dtype: float32
# INFO:  output_name.1: stem/MobilenetV3/Bottleneck_1/Bottleneck_1_1/Conv_1/Relu6 shape: [1, 16, 1, 1] dtype: float32
# INFO: tf_op_type: relu6
# INFO:  input.1.features: name: tf.math.add_4/Add:0 shape: (1, 1, 1, 16) dtype: <dtype: 'float32'>
# INFO:  input.2.min_value: shape: (1,) dtype: float32
# INFO:  input.3.max_value: shape: (1,) dtype: float32
# INFO:  output.1.output: name: tf.nn.relu6_1/Relu6:0 shape: (1, 1, 1, 16) dtype: <dtype: 'float32'>
#
# INFO: 19 / 236
# INFO: onnx_op_type: Mul onnx_op_name: sng_Mul_17
# INFO:  input_name.1: stem/MobilenetV3/Bottleneck_1/Bottleneck_1_1/Conv_1/Relu6 shape: [1, 16, 1, 1] dtype: float32
# INFO:  input_name.2: elementwise_stem/MobilenetV3/Conv2d_0/mul shape: (1,) dtype: float32
# INFO:  output_name.1: stem/MobilenetV3/Bottleneck_1/Bottleneck_1_1/Conv_1/mul shape: [1, 16, 1, 1] dtype: float32
# INFO: tf_op_type: multiply
# INFO:  input.1.x: name: tf.nn.relu6_1/Relu6:0 shape: (1, 1, 1, 16) dtype: <dtype: 'float32'>
# INFO:  input.2.y: shape: (1, 1, 1, 1) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.multiply_18/Mul:0 shape: (1, 1, 1, 16) dtype: <dtype: 'float32'>
#
# INFO: 20 / 236
# INFO: onnx_op_type: Mul onnx_op_name: sng_Mul_18
# INFO:  input_name.1: stem/MobilenetV3/Bottleneck_1/depthwise/InstanceNorm/instancenorm/add_1 shape: [1, 16, 90, 90] dtype: float32
# INFO:  input_name.2: stem/MobilenetV3/Bottleneck_1/Bottleneck_1_1/Conv_1/mul shape: [1, 16, 1, 1] dtype: float32
# INFO:  output_name.1: stem/MobilenetV3/Bottleneck_1/mul shape: [1, 16, 90, 90] dtype: float32
# INFO: tf_op_type: multiply
# INFO:  input.1.x: name: tf.__operators__.add_11/AddV2:0 shape: (1, 90, 90, 16) dtype: <dtype: 'float32'>
# INFO:  input.2.y: name: tf.math.multiply_18/Mul:0 shape: (1, 1, 1, 16) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.multiply_22/Mul:0 shape: (1, 90, 90, 16) dtype: <dtype: 'float32'>
#
# INFO: 21 / 236
# INFO: onnx_op_type: Relu onnx_op_name: sng_Relu_19
# INFO:  input_name.1: stem/MobilenetV3/Bottleneck_1/mul shape: [1, 16, 90, 90] dtype: float32
# INFO:  output_name.1: stem/MobilenetV3/Bottleneck_1/Relu shape: [1, 16, 90, 90] dtype: float32
# INFO: tf_op_type: relu
# INFO:  input.1.features: name: tf.math.multiply_22/Mul:0 shape: (1, 90, 90, 16) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.nn.relu_2/Relu:0 shape: (1, 90, 90, 16) dtype: <dtype: 'float32'>
#
# INFO: 22 / 236
# INFO: onnx_op_type: Conv onnx_op_name: sng_Conv_20
# INFO:  input_name.1: stem/MobilenetV3/Bottleneck_1/Relu shape: [1, 16, 90, 90] dtype: float32
# INFO:  input_name.2: 21 shape: [16, 16, 1, 1] dtype: float32
# INFO:  output_name.1: stem/MobilenetV3/Bottleneck_1/compress/Conv2D shape: [1, 16, 90, 90] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.nn.relu_2/Relu:0 shape: (1, 90, 90, 16) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (1, 1, 16, 16) dtype: <dtype: 'float32'>
# INFO:  input.3.bias:
# INFO:  input.4.strides: val: [1, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: SAME
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.nn.convolution_4/convolution:0 shape: (1, 90, 90, 16) dtype: <dtype: 'float32'>
#
# INFO: 23 / 236
# INFO: onnx_op_type: InstanceNormalization onnx_op_name: sng_InstanceNormalization_21
# INFO:  input_name.1: stem/MobilenetV3/Bottleneck_1/compress/Conv2D shape: [1, 16, 90, 90] dtype: float32
# INFO:  input_name.2: 23s shape: [16] dtype: float32
# INFO:  input_name.3: 23bias shape: [16] dtype: float32
# INFO:  output_name.1: stem/MobilenetV3/Bottleneck_1/compress/InstanceNorm/instancenorm/add_1 shape: [1, 16, 90, 90] dtype: float32
# INFO: tf_op_type: InstanceNormalization
# INFO:  input.1.x: name: tf.compat.v1.transpose_5/transpose:0 shape: (1, 90, 90, 16) dtype: <dtype: 'float32'>
# INFO:  input.2.mean: name: tf.math.reduce_mean_14/Mean:0 shape: (1, 1, 1, 16) dtype: <dtype: 'float32'>
# INFO:  input.3.variance: name: tf.math.reduce_mean_15/Mean:0 shape: (1, 1, 1, 16) dtype: <dtype: 'float32'>
# INFO:  input.4.offset: shape: (16,) dtype: <dtype: 'float32'>
# INFO:  input.5.scale: shape: (16,) dtype: <dtype: 'float32'>
# INFO:  input.6.variance_epsilon: shape: () dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.__operators__.add_15/AddV2:0 shape: (1, 90, 90, 16) dtype: <dtype: 'float32'>
#
# INFO: 24 / 236
# INFO: onnx_op_type: Conv onnx_op_name: sng_Conv_22
# INFO:  input_name.1: stem/MobilenetV3/Bottleneck_1/compress/InstanceNorm/instancenorm/add_1 shape: [1, 16, 90, 90] dtype: float32
# INFO:  input_name.2: 25 shape: [56, 16, 1, 1] dtype: float32
# INFO:  output_name.1: stem/MobilenetV3/Bottleneck_2/expand/Conv2D shape: [1, 56, 90, 90] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.__operators__.add_15/AddV2:0 shape: (1, 90, 90, 16) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (1, 1, 16, 56) dtype: <dtype: 'float32'>
# INFO:  input.3.bias:
# INFO:  input.4.strides: val: [1, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: SAME
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.nn.convolution_5/convolution:0 shape: (1, 90, 90, 56) dtype: <dtype: 'float32'>
#
# INFO: 25 / 236
# INFO: onnx_op_type: InstanceNormalization onnx_op_name: sng_InstanceNormalization_23
# INFO:  input_name.1: stem/MobilenetV3/Bottleneck_2/expand/Conv2D shape: [1, 56, 90, 90] dtype: float32
# INFO:  input_name.2: 27s shape: [56] dtype: float32
# INFO:  input_name.3: 27bias shape: [56] dtype: float32
# INFO:  output_name.1: stem/MobilenetV3/Bottleneck_2/expand/InstanceNorm/instancenorm/add_1 shape: [1, 56, 90, 90] dtype: float32
# INFO: tf_op_type: InstanceNormalization
# INFO:  input.1.x: name: tf.compat.v1.transpose_6/transpose:0 shape: (1, 90, 90, 56) dtype: <dtype: 'float32'>
# INFO:  input.2.mean: name: tf.math.reduce_mean_18/Mean:0 shape: (1, 1, 1, 56) dtype: <dtype: 'float32'>
# INFO:  input.3.variance: name: tf.math.reduce_mean_19/Mean:0 shape: (1, 1, 1, 56) dtype: <dtype: 'float32'>
# INFO:  input.4.offset: shape: (56,) dtype: <dtype: 'float32'>
# INFO:  input.5.scale: shape: (56,) dtype: <dtype: 'float32'>
# INFO:  input.6.variance_epsilon: shape: () dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.__operators__.add_19/AddV2:0 shape: (1, 90, 90, 56) dtype: <dtype: 'float32'>
#
# INFO: 26 / 236
# INFO: onnx_op_type: Relu onnx_op_name: sng_Relu_24
# INFO:  input_name.1: stem/MobilenetV3/Bottleneck_2/expand/InstanceNorm/instancenorm/add_1 shape: [1, 56, 90, 90] dtype: float32
# INFO:  output_name.1: stem/MobilenetV3/Bottleneck_2/expand/Relu shape: [1, 56, 90, 90] dtype: float32
# INFO: tf_op_type: relu
# INFO:  input.1.features: name: tf.__operators__.add_19/AddV2:0 shape: (1, 90, 90, 56) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.nn.relu_3/Relu:0 shape: (1, 90, 90, 56) dtype: <dtype: 'float32'>
#
# INFO: 27 / 236
# INFO: onnx_op_type: Conv onnx_op_name: sng_Conv_25
# INFO:  input_name.1: stem/MobilenetV3/Bottleneck_2/expand/Relu shape: [1, 56, 90, 90] dtype: float32
# INFO:  input_name.2: 29 shape: [56, 1, 3, 3] dtype: float32
# INFO:  output_name.1: stem/MobilenetV3/Bottleneck_2/depthwise/depthwise shape: [1, 56, 45, 45] dtype: float32
# INFO: tf_op_type: depthwise_conv2d_v2
# INFO:  input.1.input: name: tf.nn.relu_3/Relu:0 shape: (1, 90, 90, 56) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (3, 3, 56, 1) dtype: <dtype: 'float32'>
# INFO:  input.3.bias:
# INFO:  input.4.strides: val: [1, 2, 2, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: SAME
# INFO:  input.7.group: val: 56
# INFO:  output.1.output: name: tf.compat.v1.nn.depthwise_conv2d_1/depthwise:0 shape: (1, 45, 45, 56) dtype: <dtype: 'float32'>
#
# INFO: 28 / 236
# INFO: onnx_op_type: InstanceNormalization onnx_op_name: sng_InstanceNormalization_26
# INFO:  input_name.1: stem/MobilenetV3/Bottleneck_2/depthwise/depthwise shape: [1, 56, 45, 45] dtype: float32
# INFO:  input_name.2: 31s shape: [56] dtype: float32
# INFO:  input_name.3: 31bias shape: [56] dtype: float32
# INFO:  output_name.1: stem/MobilenetV3/Bottleneck_2/depthwise/InstanceNorm/instancenorm/add_1 shape: [1, 56, 45, 45] dtype: float32
# INFO: tf_op_type: InstanceNormalization
# INFO:  input.1.x: name: tf.compat.v1.transpose_7/transpose:0 shape: (1, 45, 45, 56) dtype: <dtype: 'float32'>
# INFO:  input.2.mean: name: tf.math.reduce_mean_22/Mean:0 shape: (1, 1, 1, 56) dtype: <dtype: 'float32'>
# INFO:  input.3.variance: name: tf.math.reduce_mean_23/Mean:0 shape: (1, 1, 1, 56) dtype: <dtype: 'float32'>
# INFO:  input.4.offset: shape: (56,) dtype: <dtype: 'float32'>
# INFO:  input.5.scale: shape: (56,) dtype: <dtype: 'float32'>
# INFO:  input.6.variance_epsilon: shape: () dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.__operators__.add_23/AddV2:0 shape: (1, 45, 45, 56) dtype: <dtype: 'float32'>
#
# INFO: 29 / 236
# INFO: onnx_op_type: Relu onnx_op_name: sng_Relu_27
# INFO:  input_name.1: stem/MobilenetV3/Bottleneck_2/depthwise/InstanceNorm/instancenorm/add_1 shape: [1, 56, 45, 45] dtype: float32
# INFO:  output_name.1: stem/MobilenetV3/Bottleneck_2/Relu shape: [1, 56, 45, 45] dtype: float32
# INFO: tf_op_type: relu
# INFO:  input.1.features: name: tf.__operators__.add_23/AddV2:0 shape: (1, 45, 45, 56) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.nn.relu_4/Relu:0 shape: (1, 45, 45, 56) dtype: <dtype: 'float32'>
#
# INFO: 30 / 236
# INFO: onnx_op_type: Conv onnx_op_name: sng_Conv_28
# INFO:  input_name.1: stem/MobilenetV3/Bottleneck_2/Relu shape: [1, 56, 45, 45] dtype: float32
# INFO:  input_name.2: 33 shape: [24, 56, 1, 1] dtype: float32
# INFO:  output_name.1: stem/MobilenetV3/Bottleneck_2/compress/Conv2D shape: [1, 24, 45, 45] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.nn.relu_4/Relu:0 shape: (1, 45, 45, 56) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (1, 1, 56, 24) dtype: <dtype: 'float32'>
# INFO:  input.3.bias:
# INFO:  input.4.strides: val: [1, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: SAME
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.nn.convolution_6/convolution:0 shape: (1, 45, 45, 24) dtype: <dtype: 'float32'>
#
# INFO: 31 / 236
# INFO: onnx_op_type: InstanceNormalization onnx_op_name: sng_InstanceNormalization_29
# INFO:  input_name.1: stem/MobilenetV3/Bottleneck_2/compress/Conv2D shape: [1, 24, 45, 45] dtype: float32
# INFO:  input_name.2: 35s shape: [24] dtype: float32
# INFO:  input_name.3: 35bias shape: [24] dtype: float32
# INFO:  output_name.1: stem/MobilenetV3/Bottleneck_2/compress/InstanceNorm/instancenorm/add_1 shape: [1, 24, 45, 45] dtype: float32
# INFO: tf_op_type: InstanceNormalization
# INFO:  input.1.x: name: tf.compat.v1.transpose_8/transpose:0 shape: (1, 45, 45, 24) dtype: <dtype: 'float32'>
# INFO:  input.2.mean: name: tf.math.reduce_mean_26/Mean:0 shape: (1, 1, 1, 24) dtype: <dtype: 'float32'>
# INFO:  input.3.variance: name: tf.math.reduce_mean_27/Mean:0 shape: (1, 1, 1, 24) dtype: <dtype: 'float32'>
# INFO:  input.4.offset: shape: (24,) dtype: <dtype: 'float32'>
# INFO:  input.5.scale: shape: (24,) dtype: <dtype: 'float32'>
# INFO:  input.6.variance_epsilon: shape: () dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.__operators__.add_27/AddV2:0 shape: (1, 45, 45, 24) dtype: <dtype: 'float32'>
#
# INFO: 32 / 236
# INFO: onnx_op_type: Conv onnx_op_name: sng_Conv_30
# INFO:  input_name.1: stem/MobilenetV3/Bottleneck_2/compress/InstanceNorm/instancenorm/add_1 shape: [1, 24, 45, 45] dtype: float32
# INFO:  input_name.2: 37 shape: [64, 24, 1, 1] dtype: float32
# INFO:  output_name.1: stem/MobilenetV3/Bottleneck_3/expand/Conv2D shape: [1, 64, 45, 45] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.__operators__.add_27/AddV2:0 shape: (1, 45, 45, 24) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (1, 1, 24, 64) dtype: <dtype: 'float32'>
# INFO:  input.3.bias:
# INFO:  input.4.strides: val: [1, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: SAME
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.nn.convolution_7/convolution:0 shape: (1, 45, 45, 64) dtype: <dtype: 'float32'>
#
# INFO: 33 / 236
# INFO: onnx_op_type: InstanceNormalization onnx_op_name: sng_InstanceNormalization_31
# INFO:  input_name.1: stem/MobilenetV3/Bottleneck_3/expand/Conv2D shape: [1, 64, 45, 45] dtype: float32
# INFO:  input_name.2: 39s shape: [64] dtype: float32
# INFO:  input_name.3: 39bias shape: [64] dtype: float32
# INFO:  output_name.1: stem/MobilenetV3/Bottleneck_3/expand/InstanceNorm/instancenorm/add_1 shape: [1, 64, 45, 45] dtype: float32
# INFO: tf_op_type: InstanceNormalization
# INFO:  input.1.x: name: tf.compat.v1.transpose_9/transpose:0 shape: (1, 45, 45, 64) dtype: <dtype: 'float32'>
# INFO:  input.2.mean: name: tf.math.reduce_mean_30/Mean:0 shape: (1, 1, 1, 64) dtype: <dtype: 'float32'>
# INFO:  input.3.variance: name: tf.math.reduce_mean_31/Mean:0 shape: (1, 1, 1, 64) dtype: <dtype: 'float32'>
# INFO:  input.4.offset: shape: (64,) dtype: <dtype: 'float32'>
# INFO:  input.5.scale: shape: (64,) dtype: <dtype: 'float32'>
# INFO:  input.6.variance_epsilon: shape: () dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.__operators__.add_31/AddV2:0 shape: (1, 45, 45, 64) dtype: <dtype: 'float32'>
#
# INFO: 34 / 236
# INFO: onnx_op_type: Relu onnx_op_name: sng_Relu_32
# INFO:  input_name.1: stem/MobilenetV3/Bottleneck_3/expand/InstanceNorm/instancenorm/add_1 shape: [1, 64, 45, 45] dtype: float32
# INFO:  output_name.1: stem/MobilenetV3/Bottleneck_3/expand/Relu shape: [1, 64, 45, 45] dtype: float32
# INFO: tf_op_type: relu
# INFO:  input.1.features: name: tf.__operators__.add_31/AddV2:0 shape: (1, 45, 45, 64) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.nn.relu_5/Relu:0 shape: (1, 45, 45, 64) dtype: <dtype: 'float32'>
#
# INFO: 35 / 236
# INFO: onnx_op_type: Conv onnx_op_name: sng_Conv_33
# INFO:  input_name.1: stem/MobilenetV3/Bottleneck_3/expand/Relu shape: [1, 64, 45, 45] dtype: float32
# INFO:  input_name.2: 41 shape: [64, 1, 3, 3] dtype: float32
# INFO:  output_name.1: stem/MobilenetV3/Bottleneck_3/depthwise/depthwise shape: [1, 64, 45, 45] dtype: float32
# INFO: tf_op_type: depthwise_conv2d_v2
# INFO:  input.1.input: name: tf.nn.relu_5/Relu:0 shape: (1, 45, 45, 64) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (3, 3, 64, 1) dtype: <dtype: 'float32'>
# INFO:  input.3.bias:
# INFO:  input.4.strides: val: [1, 1, 1, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: SAME
# INFO:  input.7.group: val: 64
# INFO:  output.1.output: name: tf.compat.v1.nn.depthwise_conv2d_2/depthwise:0 shape: (1, 45, 45, 64) dtype: <dtype: 'float32'>
#
# INFO: 36 / 236
# INFO: onnx_op_type: InstanceNormalization onnx_op_name: sng_InstanceNormalization_34
# INFO:  input_name.1: stem/MobilenetV3/Bottleneck_3/depthwise/depthwise shape: [1, 64, 45, 45] dtype: float32
# INFO:  input_name.2: 43s shape: [64] dtype: float32
# INFO:  input_name.3: 43bias shape: [64] dtype: float32
# INFO:  output_name.1: stem/MobilenetV3/Bottleneck_3/depthwise/InstanceNorm/instancenorm/add_1 shape: [1, 64, 45, 45] dtype: float32
# INFO: tf_op_type: InstanceNormalization
# INFO:  input.1.x: name: tf.compat.v1.transpose_10/transpose:0 shape: (1, 45, 45, 64) dtype: <dtype: 'float32'>
# INFO:  input.2.mean: name: tf.math.reduce_mean_34/Mean:0 shape: (1, 1, 1, 64) dtype: <dtype: 'float32'>
# INFO:  input.3.variance: name: tf.math.reduce_mean_35/Mean:0 shape: (1, 1, 1, 64) dtype: <dtype: 'float32'>
# INFO:  input.4.offset: shape: (64,) dtype: <dtype: 'float32'>
# INFO:  input.5.scale: shape: (64,) dtype: <dtype: 'float32'>
# INFO:  input.6.variance_epsilon: shape: () dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.__operators__.add_35/AddV2:0 shape: (1, 45, 45, 64) dtype: <dtype: 'float32'>
#
# INFO: 37 / 236
# INFO: onnx_op_type: Relu onnx_op_name: sng_Relu_35
# INFO:  input_name.1: stem/MobilenetV3/Bottleneck_3/depthwise/InstanceNorm/instancenorm/add_1 shape: [1, 64, 45, 45] dtype: float32
# INFO:  output_name.1: stem/MobilenetV3/Bottleneck_3/Relu shape: [1, 64, 45, 45] dtype: float32
# INFO: tf_op_type: relu
# INFO:  input.1.features: name: tf.__operators__.add_35/AddV2:0 shape: (1, 45, 45, 64) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.nn.relu_6/Relu:0 shape: (1, 45, 45, 64) dtype: <dtype: 'float32'>
#
# INFO: 38 / 236
# INFO: onnx_op_type: Conv onnx_op_name: sng_Conv_36
# INFO:  input_name.1: stem/MobilenetV3/Bottleneck_3/Relu shape: [1, 64, 45, 45] dtype: float32
# INFO:  input_name.2: 45 shape: [24, 64, 1, 1] dtype: float32
# INFO:  output_name.1: stem/MobilenetV3/Bottleneck_3/compress/Conv2D shape: [1, 24, 45, 45] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.nn.relu_6/Relu:0 shape: (1, 45, 45, 64) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (1, 1, 64, 24) dtype: <dtype: 'float32'>
# INFO:  input.3.bias:
# INFO:  input.4.strides: val: [1, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: SAME
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.nn.convolution_8/convolution:0 shape: (1, 45, 45, 24) dtype: <dtype: 'float32'>
#
# INFO: 39 / 236
# INFO: onnx_op_type: InstanceNormalization onnx_op_name: sng_InstanceNormalization_37
# INFO:  input_name.1: stem/MobilenetV3/Bottleneck_3/compress/Conv2D shape: [1, 24, 45, 45] dtype: float32
# INFO:  input_name.2: 47s shape: [24] dtype: float32
# INFO:  input_name.3: 47bias shape: [24] dtype: float32
# INFO:  output_name.1: stem/MobilenetV3/Bottleneck_3/compress/InstanceNorm/instancenorm/add_1 shape: [1, 24, 45, 45] dtype: float32
# INFO: tf_op_type: InstanceNormalization
# INFO:  input.1.x: name: tf.compat.v1.transpose_11/transpose:0 shape: (1, 45, 45, 24) dtype: <dtype: 'float32'>
# INFO:  input.2.mean: name: tf.math.reduce_mean_38/Mean:0 shape: (1, 1, 1, 24) dtype: <dtype: 'float32'>
# INFO:  input.3.variance: name: tf.math.reduce_mean_39/Mean:0 shape: (1, 1, 1, 24) dtype: <dtype: 'float32'>
# INFO:  input.4.offset: shape: (24,) dtype: <dtype: 'float32'>
# INFO:  input.5.scale: shape: (24,) dtype: <dtype: 'float32'>
# INFO:  input.6.variance_epsilon: shape: () dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.__operators__.add_39/AddV2:0 shape: (1, 45, 45, 24) dtype: <dtype: 'float32'>
#
# INFO: 40 / 236
# INFO: onnx_op_type: Add onnx_op_name: sng_Add_38
# INFO:  input_name.1: stem/MobilenetV3/Bottleneck_3/compress/InstanceNorm/instancenorm/add_1 shape: [1, 24, 45, 45] dtype: float32
# INFO:  input_name.2: stem/MobilenetV3/Bottleneck_2/compress/InstanceNorm/instancenorm/add_1 shape: [1, 24, 45, 45] dtype: float32
# INFO:  output_name.1: stem/MobilenetV3/Bottleneck_3/add shape: [1, 24, 45, 45] dtype: float32
# INFO: tf_op_type: add
# INFO:  input.1.x: name: tf.__operators__.add_39/AddV2:0 shape: (1, 45, 45, 24) dtype: <dtype: 'float32'>
# INFO:  input.2.y: name: tf.__operators__.add_27/AddV2:0 shape: (1, 45, 45, 24) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.add_6/Add:0 shape: (1, 45, 45, 24) dtype: <dtype: 'float32'>
#
# INFO: 41 / 236
# INFO: onnx_op_type: Conv onnx_op_name: sng_Conv_39
# INFO:  input_name.1: stem/MobilenetV3/Bottleneck_3/add shape: [1, 24, 45, 45] dtype: float32
# INFO:  input_name.2: 49 shape: [72, 24, 1, 1] dtype: float32
# INFO:  output_name.1: stem/MobilenetV3/Bottleneck_4/expand/Conv2D shape: [1, 72, 45, 45] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.math.add_6/Add:0 shape: (1, 45, 45, 24) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (1, 1, 24, 72) dtype: <dtype: 'float32'>
# INFO:  input.3.bias:
# INFO:  input.4.strides: val: [1, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: SAME
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.nn.convolution_9/convolution:0 shape: (1, 45, 45, 72) dtype: <dtype: 'float32'>
#
# INFO: 42 / 236
# INFO: onnx_op_type: InstanceNormalization onnx_op_name: sng_InstanceNormalization_40
# INFO:  input_name.1: stem/MobilenetV3/Bottleneck_4/expand/Conv2D shape: [1, 72, 45, 45] dtype: float32
# INFO:  input_name.2: 51s shape: [72] dtype: float32
# INFO:  input_name.3: 51bias shape: [72] dtype: float32
# INFO:  output_name.1: stem/MobilenetV3/Bottleneck_4/expand/InstanceNorm/instancenorm/add_1 shape: [1, 72, 45, 45] dtype: float32
# INFO: tf_op_type: InstanceNormalization
# INFO:  input.1.x: name: tf.compat.v1.transpose_13/transpose:0 shape: (1, 45, 45, 72) dtype: <dtype: 'float32'>
# INFO:  input.2.mean: name: tf.math.reduce_mean_42/Mean:0 shape: (1, 1, 1, 72) dtype: <dtype: 'float32'>
# INFO:  input.3.variance: name: tf.math.reduce_mean_43/Mean:0 shape: (1, 1, 1, 72) dtype: <dtype: 'float32'>
# INFO:  input.4.offset: shape: (72,) dtype: <dtype: 'float32'>
# INFO:  input.5.scale: shape: (72,) dtype: <dtype: 'float32'>
# INFO:  input.6.variance_epsilon: shape: () dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.__operators__.add_43/AddV2:0 shape: (1, 45, 45, 72) dtype: <dtype: 'float32'>
#
# INFO: 43 / 236
# INFO: onnx_op_type: Add onnx_op_name: sng_Add_41
# INFO:  input_name.1: stem/MobilenetV3/Bottleneck_4/expand/InstanceNorm/instancenorm/add_1 shape: [1, 72, 45, 45] dtype: float32
# INFO:  input_name.2: elementwise_stem/MobilenetV3/Conv2d_0/add shape: (1,) dtype: float32
# INFO:  output_name.1: stem/MobilenetV3/Bottleneck_4/expand/add shape: [1, 72, 45, 45] dtype: float32
# INFO: tf_op_type: add
# INFO:  input.1.x: name: tf.__operators__.add_43/AddV2:0 shape: (1, 45, 45, 72) dtype: <dtype: 'float32'>
# INFO:  input.2.y: shape: (1, 1, 1, 1) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.add_8/Add:0 shape: (1, 45, 45, 72) dtype: <dtype: 'float32'>
#
# INFO: 44 / 236
# INFO: onnx_op_type: Clip onnx_op_name: sng_Clip_42
# INFO:  input_name.1: stem/MobilenetV3/Bottleneck_4/expand/add shape: [1, 72, 45, 45] dtype: float32
# INFO:  input_name.2: elementwise_stem/MobilenetV3/Conv2d_0/Relu6alpha shape: (1,) dtype: float32
# INFO:  input_name.3: elementwise_stem/MobilenetV3/Conv2d_0/Relu6beta shape: (1,) dtype: float32
# INFO:  output_name.1: stem/MobilenetV3/Bottleneck_4/expand/Relu6 shape: [1, 72, 45, 45] dtype: float32
# INFO: tf_op_type: relu6
# INFO:  input.1.features: name: tf.math.add_8/Add:0 shape: (1, 45, 45, 72) dtype: <dtype: 'float32'>
# INFO:  input.2.min_value: shape: (1,) dtype: float32
# INFO:  input.3.max_value: shape: (1,) dtype: float32
# INFO:  output.1.output: name: tf.nn.relu6_2/Relu6:0 shape: (1, 45, 45, 72) dtype: <dtype: 'float32'>
#
# INFO: 45 / 236
# INFO: onnx_op_type: Mul onnx_op_name: sng_Mul_43
# INFO:  input_name.1: stem/MobilenetV3/Bottleneck_4/expand/Relu6 shape: [1, 72, 45, 45] dtype: float32
# INFO:  input_name.2: elementwise_stem/MobilenetV3/Conv2d_0/mul shape: (1,) dtype: float32
# INFO:  output_name.1: stem/MobilenetV3/Bottleneck_4/expand/mul shape: [1, 72, 45, 45] dtype: float32
# INFO: tf_op_type: multiply
# INFO:  input.1.x: name: tf.nn.relu6_2/Relu6:0 shape: (1, 45, 45, 72) dtype: <dtype: 'float32'>
# INFO:  input.2.y: shape: (1, 1, 1, 1) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.multiply_58/Mul:0 shape: (1, 45, 45, 72) dtype: <dtype: 'float32'>
#
# INFO: 46 / 236
# INFO: onnx_op_type: Mul onnx_op_name: sng_Mul_44
# INFO:  input_name.1: stem/MobilenetV3/Bottleneck_4/expand/InstanceNorm/instancenorm/add_1 shape: [1, 72, 45, 45] dtype: float32
# INFO:  input_name.2: stem/MobilenetV3/Bottleneck_4/expand/mul shape: [1, 72, 45, 45] dtype: float32
# INFO:  output_name.1: stem/MobilenetV3/Bottleneck_4/expand/mul_1 shape: [1, 72, 45, 45] dtype: float32
# INFO: tf_op_type: multiply
# INFO:  input.1.x: name: tf.__operators__.add_43/AddV2:0 shape: (1, 45, 45, 72) dtype: <dtype: 'float32'>
# INFO:  input.2.y: name: tf.math.multiply_58/Mul:0 shape: (1, 45, 45, 72) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.multiply_62/Mul:0 shape: (1, 45, 45, 72) dtype: <dtype: 'float32'>
#
# INFO: 47 / 236
# INFO: onnx_op_type: Conv onnx_op_name: sng_Conv_45
# INFO:  input_name.1: stem/MobilenetV3/Bottleneck_4/expand/mul_1 shape: [1, 72, 45, 45] dtype: float32
# INFO:  input_name.2: 53 shape: [72, 1, 5, 5] dtype: float32
# INFO:  output_name.1: stem/MobilenetV3/Bottleneck_4/depthwise/depthwise shape: [1, 72, 23, 23] dtype: float32
# INFO: tf_op_type: depthwise_conv2d_v2
# INFO:  input.1.input: name: tf.math.multiply_62/Mul:0 shape: (1, 45, 45, 72) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (5, 5, 72, 1) dtype: <dtype: 'float32'>
# INFO:  input.3.bias:
# INFO:  input.4.strides: val: [1, 2, 2, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: SAME
# INFO:  input.7.group: val: 72
# INFO:  output.1.output: name: tf.compat.v1.nn.depthwise_conv2d_3/depthwise:0 shape: (1, 23, 23, 72) dtype: <dtype: 'float32'>
#
# INFO: 48 / 236
# INFO: onnx_op_type: InstanceNormalization onnx_op_name: sng_InstanceNormalization_46
# INFO:  input_name.1: stem/MobilenetV3/Bottleneck_4/depthwise/depthwise shape: [1, 72, 23, 23] dtype: float32
# INFO:  input_name.2: 55s shape: [72] dtype: float32
# INFO:  input_name.3: 55bias shape: [72] dtype: float32
# INFO:  output_name.1: stem/MobilenetV3/Bottleneck_4/depthwise/InstanceNorm/instancenorm/add_1 shape: [1, 72, 23, 23] dtype: float32
# INFO: tf_op_type: InstanceNormalization
# INFO:  input.1.x: name: tf.compat.v1.transpose_15/transpose:0 shape: (1, 23, 23, 72) dtype: <dtype: 'float32'>
# INFO:  input.2.mean: name: tf.math.reduce_mean_46/Mean:0 shape: (1, 1, 1, 72) dtype: <dtype: 'float32'>
# INFO:  input.3.variance: name: tf.math.reduce_mean_47/Mean:0 shape: (1, 1, 1, 72) dtype: <dtype: 'float32'>
# INFO:  input.4.offset: shape: (72,) dtype: <dtype: 'float32'>
# INFO:  input.5.scale: shape: (72,) dtype: <dtype: 'float32'>
# INFO:  input.6.variance_epsilon: shape: () dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.__operators__.add_47/AddV2:0 shape: (1, 23, 23, 72) dtype: <dtype: 'float32'>
#
# INFO: 49 / 236
# INFO: onnx_op_type: AveragePool onnx_op_name: sng_AveragePool_47
# INFO:  input_name.1: stem/MobilenetV3/Bottleneck_4/depthwise/InstanceNorm/instancenorm/add_1 shape: [1, 72, 23, 23] dtype: float32
# INFO:  output_name.1: stem/MobilenetV3/Bottleneck_4/gap/Mean shape: [1, 72, 1, 1] dtype: float32
# INFO: tf_op_type: AveragePooling2D
# INFO:  input.1.x: name: tf.__operators__.add_47/AddV2:0 shape: (1, 23, 23, 72) dtype: <dtype: 'float32'>
# INFO:  input.2.pool_size: val: [23, 23]
# INFO:  input.3.strides: val: [1, 1]
# INFO:  input.4.padding: val: [0, 0, 0, 0]
# INFO:  output.1.output: name: tf.compat.v1.nn.avg_pool_1/AvgPool:0 shape: (1, 1, 1, 72) dtype: <dtype: 'float32'>
#
# INFO: 50 / 236
# INFO: onnx_op_type: Conv onnx_op_name: sng_Conv_48
# INFO:  input_name.1: stem/MobilenetV3/Bottleneck_4/gap/Mean shape: [1, 72, 1, 1] dtype: float32
# INFO:  input_name.2: 59 shape: [18, 72, 1, 1] dtype: float32
# INFO:  input_name.3: 57 shape: [18] dtype: float32
# INFO:  output_name.1: conv_stem/MobilenetV3/Bottleneck_4/Bottleneck_4/Conv/Conv2D shape: [1, 18, 1, 1] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.compat.v1.nn.avg_pool_1/AvgPool:0 shape: (1, 1, 1, 72) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (1, 1, 72, 18) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (18,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [1, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: SAME
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.math.add_9/Add:0 shape: (1, 1, 1, 18) dtype: <dtype: 'float32'>
#
# INFO: 51 / 236
# INFO: onnx_op_type: Relu onnx_op_name: sng_Relu_49
# INFO:  input_name.1: conv_stem/MobilenetV3/Bottleneck_4/Bottleneck_4/Conv/Conv2D shape: [1, 18, 1, 1] dtype: float32
# INFO:  output_name.1: stem/MobilenetV3/Bottleneck_4/Bottleneck_4/Conv/Conv2D shape: [1, 18, 1, 1] dtype: float32
# INFO: tf_op_type: relu
# INFO:  input.1.features: name: tf.math.add_9/Add:0 shape: (1, 1, 1, 18) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.nn.relu_7/Relu:0 shape: (1, 1, 1, 18) dtype: <dtype: 'float32'>
#
# INFO: 52 / 236
# INFO: onnx_op_type: Conv onnx_op_name: sng_Conv_50
# INFO:  input_name.1: stem/MobilenetV3/Bottleneck_4/Bottleneck_4/Conv/Conv2D shape: [1, 18, 1, 1] dtype: float32
# INFO:  input_name.2: 63 shape: [72, 18, 1, 1] dtype: float32
# INFO:  input_name.3: 61 shape: [72] dtype: float32
# INFO:  output_name.1: stem/MobilenetV3/Bottleneck_4/Bottleneck_4_1/Conv_1/Conv2D shape: [1, 72, 1, 1] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.nn.relu_7/Relu:0 shape: (1, 1, 1, 18) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (1, 1, 18, 72) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (72,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [1, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: SAME
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.math.add_10/Add:0 shape: (1, 1, 1, 72) dtype: <dtype: 'float32'>
#
# INFO: 53 / 236
# INFO: onnx_op_type: Add onnx_op_name: sng_Add_51
# INFO:  input_name.1: stem/MobilenetV3/Bottleneck_4/Bottleneck_4_1/Conv_1/Conv2D shape: [1, 72, 1, 1] dtype: float32
# INFO:  input_name.2: elementwise_stem/MobilenetV3/Conv2d_0/add shape: (1,) dtype: float32
# INFO:  output_name.1: stem/MobilenetV3/Bottleneck_4/Bottleneck_4_1/Conv_1/add shape: [1, 72, 1, 1] dtype: float32
# INFO: tf_op_type: add
# INFO:  input.1.x: name: tf.math.add_10/Add:0 shape: (1, 1, 1, 72) dtype: <dtype: 'float32'>
# INFO:  input.2.y: shape: (1, 1, 1, 1) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.add_11/Add:0 shape: (1, 1, 1, 72) dtype: <dtype: 'float32'>
#
# INFO: 54 / 236
# INFO: onnx_op_type: Clip onnx_op_name: sng_Clip_52
# INFO:  input_name.1: stem/MobilenetV3/Bottleneck_4/Bottleneck_4_1/Conv_1/add shape: [1, 72, 1, 1] dtype: float32
# INFO:  input_name.2: elementwise_stem/MobilenetV3/Conv2d_0/Relu6alpha shape: (1,) dtype: float32
# INFO:  input_name.3: elementwise_stem/MobilenetV3/Conv2d_0/Relu6beta shape: (1,) dtype: float32
# INFO:  output_name.1: stem/MobilenetV3/Bottleneck_4/Bottleneck_4_1/Conv_1/Relu6 shape: [1, 72, 1, 1] dtype: float32
# INFO: tf_op_type: relu6
# INFO:  input.1.features: name: tf.math.add_11/Add:0 shape: (1, 1, 1, 72) dtype: <dtype: 'float32'>
# INFO:  input.2.min_value: shape: (1,) dtype: float32
# INFO:  input.3.max_value: shape: (1,) dtype: float32
# INFO:  output.1.output: name: tf.nn.relu6_3/Relu6:0 shape: (1, 1, 1, 72) dtype: <dtype: 'float32'>
#
# INFO: 55 / 236
# INFO: onnx_op_type: Mul onnx_op_name: sng_Mul_53
# INFO:  input_name.1: stem/MobilenetV3/Bottleneck_4/Bottleneck_4_1/Conv_1/Relu6 shape: [1, 72, 1, 1] dtype: float32
# INFO:  input_name.2: elementwise_stem/MobilenetV3/Conv2d_0/mul shape: (1,) dtype: float32
# INFO:  output_name.1: stem/MobilenetV3/Bottleneck_4/Bottleneck_4_1/Conv_1/mul shape: [1, 72, 1, 1] dtype: float32
# INFO: tf_op_type: multiply
# INFO:  input.1.x: name: tf.nn.relu6_3/Relu6:0 shape: (1, 1, 1, 72) dtype: <dtype: 'float32'>
# INFO:  input.2.y: shape: (1, 1, 1, 1) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.multiply_67/Mul:0 shape: (1, 1, 1, 72) dtype: <dtype: 'float32'>
#
# INFO: 56 / 236
# INFO: onnx_op_type: Mul onnx_op_name: sng_Mul_54
# INFO:  input_name.1: stem/MobilenetV3/Bottleneck_4/depthwise/InstanceNorm/instancenorm/add_1 shape: [1, 72, 23, 23] dtype: float32
# INFO:  input_name.2: stem/MobilenetV3/Bottleneck_4/Bottleneck_4_1/Conv_1/mul shape: [1, 72, 1, 1] dtype: float32
# INFO:  output_name.1: stem/MobilenetV3/Bottleneck_4/mul shape: [1, 72, 23, 23] dtype: float32
# INFO: tf_op_type: multiply
# INFO:  input.1.x: name: tf.__operators__.add_47/AddV2:0 shape: (1, 23, 23, 72) dtype: <dtype: 'float32'>
# INFO:  input.2.y: name: tf.math.multiply_67/Mul:0 shape: (1, 1, 1, 72) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.multiply_71/Mul:0 shape: (1, 23, 23, 72) dtype: <dtype: 'float32'>
#
# INFO: 57 / 236
# INFO: onnx_op_type: Add onnx_op_name: sng_Add_55
# INFO:  input_name.1: stem/MobilenetV3/Bottleneck_4/mul shape: [1, 72, 23, 23] dtype: float32
# INFO:  input_name.2: elementwise_stem/MobilenetV3/Conv2d_0/add shape: (1,) dtype: float32
# INFO:  output_name.1: stem/MobilenetV3/Bottleneck_4/add shape: [1, 72, 23, 23] dtype: float32
# INFO: tf_op_type: add
# INFO:  input.1.x: name: tf.math.multiply_71/Mul:0 shape: (1, 23, 23, 72) dtype: <dtype: 'float32'>
# INFO:  input.2.y: shape: (1, 1, 1, 1) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.add_13/Add:0 shape: (1, 23, 23, 72) dtype: <dtype: 'float32'>
#
# INFO: 58 / 236
# INFO: onnx_op_type: Clip onnx_op_name: sng_Clip_56
# INFO:  input_name.1: stem/MobilenetV3/Bottleneck_4/add shape: [1, 72, 23, 23] dtype: float32
# INFO:  input_name.2: elementwise_stem/MobilenetV3/Conv2d_0/Relu6alpha shape: (1,) dtype: float32
# INFO:  input_name.3: elementwise_stem/MobilenetV3/Conv2d_0/Relu6beta shape: (1,) dtype: float32
# INFO:  output_name.1: stem/MobilenetV3/Bottleneck_4/Relu6 shape: [1, 72, 23, 23] dtype: float32
# INFO: tf_op_type: relu6
# INFO:  input.1.features: name: tf.math.add_13/Add:0 shape: (1, 23, 23, 72) dtype: <dtype: 'float32'>
# INFO:  input.2.min_value: shape: (1,) dtype: float32
# INFO:  input.3.max_value: shape: (1,) dtype: float32
# INFO:  output.1.output: name: tf.nn.relu6_4/Relu6:0 shape: (1, 23, 23, 72) dtype: <dtype: 'float32'>
#
# INFO: 59 / 236
# INFO: onnx_op_type: Mul onnx_op_name: sng_Mul_57
# INFO:  input_name.1: stem/MobilenetV3/Bottleneck_4/Relu6 shape: [1, 72, 23, 23] dtype: float32
# INFO:  input_name.2: elementwise_stem/MobilenetV3/Conv2d_0/mul shape: (1,) dtype: float32
# INFO:  output_name.1: stem/MobilenetV3/Bottleneck_4/mul_1 shape: [1, 72, 23, 23] dtype: float32
# ...
# INFO: tf_op_type: multiply
# INFO:  input.1.x: name: tf.nn.relu6_25/Relu6:0 shape: (1, 12, 12, 432) dtype: <dtype: 'float32'>
# INFO:  input.2.y: shape: (1, 1, 1, 1) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.multiply_284/Mul:0 shape: (1, 12, 12, 432) dtype: <dtype: 'float32'>
#
# INFO: 218 / 236
# INFO: onnx_op_type: Mul onnx_op_name: sng_Mul_216
# INFO:  input_name.1: stem/MobilenetV3/Bottleneck_11/mul shape: [1, 432, 12, 12] dtype: float32
# INFO:  input_name.2: stem/MobilenetV3/Bottleneck_11/mul_1 shape: [1, 432, 12, 12] dtype: float32
# INFO:  output_name.1: stem/MobilenetV3/Bottleneck_11/mul_2 shape: [1, 432, 12, 12] dtype: float32
# INFO: tf_op_type: multiply
# INFO:  input.1.x: name: tf.math.multiply_282/Mul:0 shape: (1, 12, 12, 432) dtype: <dtype: 'float32'>
# INFO:  input.2.y: name: tf.math.multiply_284/Mul:0 shape: (1, 12, 12, 432) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.multiply_288/Mul:0 shape: (1, 12, 12, 432) dtype: <dtype: 'float32'>
#
# INFO: 219 / 236
# INFO: onnx_op_type: Conv onnx_op_name: sng_Conv_217
# INFO:  input_name.1: stem/MobilenetV3/Bottleneck_11/mul_2 shape: [1, 432, 12, 12] dtype: float32
# INFO:  input_name.2: 205 shape: [72, 432, 1, 1] dtype: float32
# INFO:  output_name.1: stem/MobilenetV3/Bottleneck_11/compress/Conv2D shape: [1, 72, 12, 12] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.math.multiply_288/Mul:0 shape: (1, 12, 12, 432) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (1, 1, 432, 72) dtype: <dtype: 'float32'>
# INFO:  input.3.bias:
# INFO:  input.4.strides: val: [1, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: SAME
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.nn.convolution_40/convolution:0 shape: (1, 12, 12, 72) dtype: <dtype: 'float32'>
#
# INFO: 220 / 236
# INFO: onnx_op_type: InstanceNormalization onnx_op_name: sng_InstanceNormalization_218
# INFO:  input_name.1: stem/MobilenetV3/Bottleneck_11/compress/Conv2D shape: [1, 72, 12, 12] dtype: float32
# INFO:  input_name.2: 207s shape: [72] dtype: float32
# INFO:  input_name.3: 207bias shape: [72] dtype: float32
# INFO:  output_name.1: stem/MobilenetV3/Bottleneck_11/compress/InstanceNorm/instancenorm/add_1 shape: [1, 72, 12, 12] dtype: float32
# INFO: tf_op_type: InstanceNormalization
# INFO:  input.1.x: name: tf.compat.v1.transpose_64/transpose:0 shape: (1, 12, 12, 72) dtype: <dtype: 'float32'>
# INFO:  input.2.mean: name: tf.math.reduce_mean_134/Mean:0 shape: (1, 1, 1, 72) dtype: <dtype: 'float32'>
# INFO:  input.3.variance: name: tf.math.reduce_mean_135/Mean:0 shape: (1, 1, 1, 72) dtype: <dtype: 'float32'>
# INFO:  input.4.offset: shape: (72,) dtype: <dtype: 'float32'>
# INFO:  input.5.scale: shape: (72,) dtype: <dtype: 'float32'>
# INFO:  input.6.variance_epsilon: shape: () dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.__operators__.add_135/AddV2:0 shape: (1, 12, 12, 72) dtype: <dtype: 'float32'>
#
# INFO: 221 / 236
# INFO: onnx_op_type: Add onnx_op_name: sng_Add_219
# INFO:  input_name.1: stem/MobilenetV3/Bottleneck_11/compress/InstanceNorm/instancenorm/add_1 shape: [1, 72, 12, 12] dtype: float32
# INFO:  input_name.2: stem/MobilenetV3/Bottleneck_10/add_1 shape: [1, 72, 12, 12] dtype: float32
# INFO:  output_name.1: stem/MobilenetV3/Bottleneck_11/add_1 shape: [1, 72, 12, 12] dtype: float32
# INFO: tf_op_type: add
# INFO:  input.1.x: name: tf.__operators__.add_135/AddV2:0 shape: (1, 12, 12, 72) dtype: <dtype: 'float32'>
# INFO:  input.2.y: name: tf.math.add_63/Add:0 shape: (1, 12, 12, 72) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.add_72/Add:0 shape: (1, 12, 12, 72) dtype: <dtype: 'float32'>
#
# INFO: 222 / 236
# INFO: onnx_op_type: Conv onnx_op_name: sng_Conv_220
# INFO:  input_name.1: stem/MobilenetV3/Bottleneck_11/add_1 shape: [1, 72, 12, 12] dtype: float32
# INFO:  input_name.2: 209 shape: [432, 72, 1, 1] dtype: float32
# INFO:  output_name.1: stem/MobilenetV3/Conv2d_12/Conv2D shape: [1, 432, 12, 12] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.math.add_72/Add:0 shape: (1, 12, 12, 72) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (1, 1, 72, 432) dtype: <dtype: 'float32'>
# INFO:  input.3.bias:
# INFO:  input.4.strides: val: [1, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: SAME
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.nn.convolution_41/convolution:0 shape: (1, 12, 12, 432) dtype: <dtype: 'float32'>
#
# INFO: 223 / 236
# INFO: onnx_op_type: InstanceNormalization onnx_op_name: sng_InstanceNormalization_221
# INFO:  input_name.1: stem/MobilenetV3/Conv2d_12/Conv2D shape: [1, 432, 12, 12] dtype: float32
# INFO:  input_name.2: 211s shape: [432] dtype: float32
# INFO:  input_name.3: 211bias shape: [432] dtype: float32
# INFO:  output_name.1: stem/MobilenetV3/Conv2d_12/InstanceNorm/instancenorm/add_1 shape: [1, 432, 12, 12] dtype: float32
# INFO: tf_op_type: InstanceNormalization
# INFO:  input.1.x: name: tf.compat.v1.transpose_66/transpose:0 shape: (1, 12, 12, 432) dtype: <dtype: 'float32'>
# INFO:  input.2.mean: name: tf.math.reduce_mean_138/Mean:0 shape: (1, 1, 1, 432) dtype: <dtype: 'float32'>
# INFO:  input.3.variance: name: tf.math.reduce_mean_139/Mean:0 shape: (1, 1, 1, 432) dtype: <dtype: 'float32'>
# INFO:  input.4.offset: shape: (432,) dtype: <dtype: 'float32'>
# INFO:  input.5.scale: shape: (432,) dtype: <dtype: 'float32'>
# INFO:  input.6.variance_epsilon: shape: () dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.__operators__.add_139/AddV2:0 shape: (1, 12, 12, 432) dtype: <dtype: 'float32'>
#
# INFO: 224 / 236
# INFO: onnx_op_type: Add onnx_op_name: sng_Add_222
# INFO:  input_name.1: stem/MobilenetV3/Conv2d_12/InstanceNorm/instancenorm/add_1 shape: [1, 432, 12, 12] dtype: float32
# INFO:  input_name.2: elementwise_stem/MobilenetV3/Conv2d_0/add shape: (1,) dtype: float32
# INFO:  output_name.1: stem/MobilenetV3/Conv2d_12/add shape: [1, 432, 12, 12] dtype: float32
# INFO: tf_op_type: add
# INFO:  input.1.x: name: tf.__operators__.add_139/AddV2:0 shape: (1, 12, 12, 432) dtype: <dtype: 'float32'>
# INFO:  input.2.y: shape: (1, 1, 1, 1) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.add_74/Add:0 shape: (1, 12, 12, 432) dtype: <dtype: 'float32'>
#
# INFO: 225 / 236
# INFO: onnx_op_type: Clip onnx_op_name: sng_Clip_223
# INFO:  input_name.1: stem/MobilenetV3/Conv2d_12/add shape: [1, 432, 12, 12] dtype: float32
# INFO:  input_name.2: elementwise_stem/MobilenetV3/Conv2d_0/Relu6alpha shape: (1,) dtype: float32
# INFO:  input_name.3: elementwise_stem/MobilenetV3/Conv2d_0/Relu6beta shape: (1,) dtype: float32
# INFO:  output_name.1: stem/MobilenetV3/Conv2d_12/Relu6 shape: [1, 432, 12, 12] dtype: float32
# INFO: tf_op_type: relu6
# INFO:  input.1.features: name: tf.math.add_74/Add:0 shape: (1, 12, 12, 432) dtype: <dtype: 'float32'>
# INFO:  input.2.min_value: shape: (1,) dtype: float32
# INFO:  input.3.max_value: shape: (1,) dtype: float32
# INFO:  output.1.output: name: tf.nn.relu6_26/Relu6:0 shape: (1, 12, 12, 432) dtype: <dtype: 'float32'>
#
# INFO: 226 / 236
# INFO: onnx_op_type: Mul onnx_op_name: sng_Mul_224
# INFO:  input_name.1: stem/MobilenetV3/Conv2d_12/Relu6 shape: [1, 432, 12, 12] dtype: float32
# INFO:  input_name.2: elementwise_stem/MobilenetV3/Conv2d_0/mul shape: (1,) dtype: float32
# INFO:  output_name.1: stem/MobilenetV3/Conv2d_12/mul shape: [1, 432, 12, 12] dtype: float32
# INFO: tf_op_type: multiply
# INFO:  input.1.x: name: tf.nn.relu6_26/Relu6:0 shape: (1, 12, 12, 432) dtype: <dtype: 'float32'>
# INFO:  input.2.y: shape: (1, 1, 1, 1) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.multiply_300/Mul:0 shape: (1, 12, 12, 432) dtype: <dtype: 'float32'>
#
# INFO: 227 / 236
# INFO: onnx_op_type: Mul onnx_op_name: sng_Mul_225
# INFO:  input_name.1: stem/MobilenetV3/Conv2d_12/InstanceNorm/instancenorm/add_1 shape: [1, 432, 12, 12] dtype: float32
# INFO:  input_name.2: stem/MobilenetV3/Conv2d_12/mul shape: [1, 432, 12, 12] dtype: float32
# INFO:  output_name.1: stem/MobilenetV3/Conv2d_12/mul_1 shape: [1, 432, 12, 12] dtype: float32
# INFO: tf_op_type: multiply
# INFO:  input.1.x: name: tf.__operators__.add_139/AddV2:0 shape: (1, 12, 12, 432) dtype: <dtype: 'float32'>
# INFO:  input.2.y: name: tf.math.multiply_300/Mul:0 shape: (1, 12, 12, 432) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.multiply_304/Mul:0 shape: (1, 12, 12, 432) dtype: <dtype: 'float32'>
#
# INFO: 228 / 236
# INFO: onnx_op_type: AveragePool onnx_op_name: sng_AveragePool_226
# INFO:  input_name.1: stem/MobilenetV3/Conv2d_12/mul_1 shape: [1, 432, 12, 12] dtype: float32
# INFO:  output_name.1: stem/MobilenetV3/Mean shape: [1, 432, 1, 1] dtype: float32
# INFO: tf_op_type: AveragePooling2D
# INFO:  input.1.x: name: tf.math.multiply_304/Mul:0 shape: (1, 12, 12, 432) dtype: <dtype: 'float32'>
# INFO:  input.2.pool_size: val: [12, 12]
# INFO:  input.3.strides: val: [1, 1]
# INFO:  input.4.padding: val: [0, 0, 0, 0]
# INFO:  output.1.output: name: tf.compat.v1.nn.avg_pool_9/AvgPool:0 shape: (1, 1, 1, 432) dtype: <dtype: 'float32'>
#
# INFO: 229 / 236
# INFO: onnx_op_type: Conv onnx_op_name: sng_Conv_227
# INFO:  input_name.1: stem/MobilenetV3/Mean shape: [1, 432, 1, 1] dtype: float32
# INFO:  input_name.2: 215 shape: [1280, 432, 1, 1] dtype: float32
# INFO:  input_name.3: 213 shape: [1280] dtype: float32
# INFO:  output_name.1: stem/MobilenetV3/GAP_13/Conv2D shape: [1, 1280, 1, 1] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.compat.v1.nn.avg_pool_9/AvgPool:0 shape: (1, 1, 1, 432) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (1, 1, 432, 1280) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (1280,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [1, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: SAME
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.math.add_75/Add:0 shape: (1, 1, 1, 1280) dtype: <dtype: 'float32'>
#
# INFO: 230 / 236
# INFO: onnx_op_type: Add onnx_op_name: sng_Add_228
# INFO:  input_name.1: stem/MobilenetV3/GAP_13/Conv2D shape: [1, 1280, 1, 1] dtype: float32
# INFO:  input_name.2: elementwise_stem/MobilenetV3/Conv2d_0/add shape: (1,) dtype: float32
# INFO:  output_name.1: stem/MobilenetV3/GAP_13/add shape: [1, 1280, 1, 1] dtype: float32
# INFO: tf_op_type: add
# INFO:  input.1.x: name: tf.math.add_75/Add:0 shape: (1, 1, 1, 1280) dtype: <dtype: 'float32'>
# INFO:  input.2.y: shape: (1, 1, 1, 1) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.add_76/Add:0 shape: (1, 1, 1, 1280) dtype: <dtype: 'float32'>
#
# INFO: 231 / 236
# INFO: onnx_op_type: Clip onnx_op_name: sng_Clip_229
# INFO:  input_name.1: stem/MobilenetV3/GAP_13/add shape: [1, 1280, 1, 1] dtype: float32
# INFO:  input_name.2: elementwise_stem/MobilenetV3/Conv2d_0/Relu6alpha shape: (1,) dtype: float32
# INFO:  input_name.3: elementwise_stem/MobilenetV3/Conv2d_0/Relu6beta shape: (1,) dtype: float32
# INFO:  output_name.1: stem/MobilenetV3/GAP_13/Relu6 shape: [1, 1280, 1, 1] dtype: float32
# INFO: tf_op_type: relu6
# INFO:  input.1.features: name: tf.math.add_76/Add:0 shape: (1, 1, 1, 1280) dtype: <dtype: 'float32'>
# INFO:  input.2.min_value: shape: (1,) dtype: float32
# INFO:  input.3.max_value: shape: (1,) dtype: float32
# INFO:  output.1.output: name: tf.nn.relu6_27/Relu6:0 shape: (1, 1, 1, 1280) dtype: <dtype: 'float32'>
#
# INFO: 232 / 236
# INFO: onnx_op_type: Mul onnx_op_name: sng_Mul_230
# INFO:  input_name.1: stem/MobilenetV3/GAP_13/Relu6 shape: [1, 1280, 1, 1] dtype: float32
# INFO:  input_name.2: elementwise_stem/MobilenetV3/Conv2d_0/mul shape: (1,) dtype: float32
# INFO:  output_name.1: stem/MobilenetV3/GAP_13/mul shape: [1, 1280, 1, 1] dtype: float32
# INFO: tf_op_type: multiply
# INFO:  input.1.x: name: tf.nn.relu6_27/Relu6:0 shape: (1, 1, 1, 1280) dtype: <dtype: 'float32'>
# INFO:  input.2.y: shape: (1, 1, 1, 1) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.multiply_305/Mul:0 shape: (1, 1, 1, 1280) dtype: <dtype: 'float32'>
#
# INFO: 233 / 236
# INFO: onnx_op_type: Mul onnx_op_name: sng_Mul_231
# INFO:  input_name.1: stem/MobilenetV3/GAP_13/Conv2D shape: [1, 1280, 1, 1] dtype: float32
# INFO:  input_name.2: stem/MobilenetV3/GAP_13/mul shape: [1, 1280, 1, 1] dtype: float32
# INFO:  output_name.1: stem/MobilenetV3/GAP_13/mul_1 shape: [1, 1280, 1, 1] dtype: float32
# INFO: tf_op_type: multiply
# INFO:  input.1.x: name: tf.math.add_75/Add:0 shape: (1, 1, 1, 1280) dtype: <dtype: 'float32'>
# INFO:  input.2.y: name: tf.math.multiply_305/Mul:0 shape: (1, 1, 1, 1280) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.multiply_308/Mul:0 shape: (1, 1, 1, 1280) dtype: <dtype: 'float32'>
#
# INFO: 234 / 236
# INFO: onnx_op_type: Conv onnx_op_name: sng_Conv_232
# INFO:  input_name.1: stem/MobilenetV3/GAP_13/mul_1 shape: [1, 1280, 1, 1] dtype: float32
# INFO:  input_name.2: 219 shape: [500, 1280, 1, 1] dtype: float32
# INFO:  input_name.3: 217 shape: [500] dtype: float32
# INFO:  output_name.1: conv_cell_leaf/fully_connected_1/MatMul shape: [1, 500, 1, 1] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.math.multiply_308/Mul:0 shape: (1, 1, 1, 1280) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (1, 1, 1280, 500) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (500,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [1, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: SAME
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.math.add_77/Add:0 shape: (1, 1, 1, 500) dtype: <dtype: 'float32'>
#
# INFO: 235 / 236
# INFO: onnx_op_type: Relu onnx_op_name: sng_Relu_233
# INFO:  input_name.1: conv_cell_leaf/fully_connected_1/MatMul shape: [1, 500, 1, 1] dtype: float32
# INFO:  output_name.1: cell_leaf/fully_connected_1/MatMul shape: [1, 500, 1, 1] dtype: float32
# INFO: tf_op_type: relu
# INFO:  input.1.features: name: tf.math.add_77/Add:0 shape: (1, 1, 1, 500) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.nn.relu_15/Relu:0 shape: (1, 1, 1, 500) dtype: <dtype: 'float32'>
#
# INFO: 236 / 236
# INFO: onnx_op_type: Conv onnx_op_name: sng_Conv_234
# INFO:  input_name.1: cell_leaf/fully_connected_1/MatMul shape: [1, 500, 1, 1] dtype: float32
# INFO:  input_name.2: 223 shape: [128, 500, 1, 1] dtype: float32
# INFO:  input_name.3: 221 shape: [128] dtype: float32
# INFO:  output_name.1: leaf/logits shape: [1, 128, 1, 1] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.nn.relu_15/Relu:0 shape: (1, 1, 1, 500) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (1, 1, 500, 128) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (128,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [1, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: SAME
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.math.add_78/Add:0 shape: (1, 1, 1, 128) dtype: <dtype: 'float32'>
#
# saved_model output started ==========================================================
# saved_model output complete!
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1744546084.806157 6599105 devices.cc:76] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0 (Note: TensorFlow was not compiled with CUDA or ROCm support)
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# W0000 00:00:1744546085.244482 6599105 tf_tfl_flatbuffer_helpers.cc:392] Ignored output_format.
# W0000 00:00:1744546085.244532 6599105 tf_tfl_flatbuffer_helpers.cc:395] Ignored drop_control_dependency.
# I0000 00:00:1744546085.476019 6599105 devices.cc:76] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0 (Note: TensorFlow was not compiled with CUDA or ROCm support)
# Float32 tflite output complete!
# Float16 tflite output complete!
# W0000 00:00:1744546085.801759 6599105 tf_tfl_flatbuffer_helpers.cc:392] Ignored output_format.
# W0000 00:00:1744546085.801769 6599105 tf_tfl_flatbuffer_helpers.cc:395] Ignored drop_control_dependency.

# %% [markdown]
# Necessary functions

# %%
import numpy as np
from PIL import Image

def load_image_tf(path):
    im = Image.open(path).convert('RGB')
    im = im.resize([360, 360])
    arr = np.array(im).astype(np.float32) / 255.0
    arr = arr.reshape([1, 360, 360, 3])
    return arr

def save_image(arr, path):
    arr = arr.reshape([360, 360, 3]) # changes shape of array from (1, 360, 360, 3) to (360, 360, 3)
    arr = (arr) * (255.0)
    arr = arr.astype(np.uint8)
    im = Image.fromarray(arr)
    im.save(path)

def load_seed(path):
    seed = open(path, 'rb').read()[128:]
    seed = np.frombuffer(seed, dtype=np.float32)
    seed = seed.reshape([96, 128])
    return seed

def hash_from_hex(hex_repr):
    n = int(hex_repr, 16)
    h = np.zeros(96)
    for i in range(96):
        h[i] = (n >> (95 - i)) & 1
    return h

def hash_to_hex(h):
    bits = ''.join(['1' if i >= 0.5 else '0' for i in h])
    return '{:0{}x}'.format(int(bits, 2), len(bits) // 4)

# %% [markdown]
# In the cell below we go thru the method by which our tf2 keras model is converted into its serialzed form so that it can be deployed in a tf1 graph session.

# %%
import tensorflow as tf
import numpy as np
import os

tf.compat.v1.disable_eager_execution()
tf.keras.backend.clear_session()

"""
Our main goal is to run a tf1 session which executes the graph version of 
tf_model.
Because our model is a tf2 keras model what we're demanding is a tough ask,  
since one can only convert tf_model into a tf2 graph which isn't executable
on tf1 sessions (due to tf2's management of a graph's content as variables,
which tf1 has no idea how to handle)
"""

"""
The first step is to just convert your model into a tf2 graph, or what is 
known as a static graph and this is done by tracing the model 
thru this decorator business
"""

from tensorflow.python.framework.convert_to_constants import convert_variables_to_constants_v2

"""
In the lines below we use the @ decorator to convert our tf_model func
into its graph equivalent. 
This only produces a template graph, to generate the version which u can execute on
we need to do the .get_concrete_function() call.
As it stands we now have our tf2 graph, which is a fine object. You will
be able to eagerly execute your model on inputs, and your tf2 graph will
do what its supposed to and execute in a graph way.
The problem is that you can't, as it stands, execute this graph in a tf1 
session.
"""

model = tf_model
@tf.function(input_signature=[tf.TensorSpec([1, 360, 360, 3], tf.float32)])
def model_func(x):
    return model(x)
concrete_func = model_func.get_concrete_function()

"""
To convert our graph so that we can run a tf1 sess on it,
we will produce a blank tf1 graph, work within it and then 
populate it with our tf2 graph's values.
To populate a blank graph with another graph we need serialize 
the latter graph using .graph.as_graph_def and then load it in
a tf1 session using tf.import_graph_def to get 
the unseralized version of the graph (i.e. our desired graph).
The convert_variables_to_constants_v2 call converts the 
values in your graph from type variables to type constants. 
We need to do this so that we get our graph to the point
whereby its eligible to be converted into its pb format (serialzed form) and 
so it's exportable to tf1.
"""

frozen_func = convert_variables_to_constants_v2(concrete_func)

"""
The below converts our graph into pb format.
"""

graph_def = frozen_func.graph.as_graph_def()

"""
Creates our blank graph.
"""

graph = tf.Graph()
# Out:
# I0000 00:00:1744546182.665960 6599105 devices.cc:76] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0 (Note: TensorFlow was not compiled with CUDA or ROCm support)

# %% [markdown]
# In the cell below we use the seralized form of our tf model to build its equivalent tf1 graph. Moreover we extend the graph so that upon running a session on it we are able to achieve values which are required for our ultimate on the cat image.

# %%
"""
The with loop below allows us to work with our 
blank tf1 graph.
"""

with graph.as_default():

    """
    We will build our desired graph by populating 
    our blank graph with our tf2 graph using the pb version of the tf2 graph.
    This is done thru the tf.import_graph_def call below.
    """
    
    tf.import_graph_def(graph_def, name="")

    """
    Now that we have the tf1 graph equiavlent of our model, we refer to 
    the input and output of our model by the name of the "nodes" in 
    the tf1 graph which correspond to those objects.
    Moreover, when we define a new variable in terms of an old one (such 
    as here: logits = tf.reshape(logits_raw, (128,))) we are effectively 
    creating a new node within the graph which we can then recover 
    upon the execution of the graph (in the same way that we do to 
    get, say, the output node.
    Finally, we can also create new nodes which don't have to be in terms of old 
    nodes thru this "placeholder" method. We want to do this so that we can 
    input in fixed values when we run the session, and this is done by 
    specifying the placeholder value.
    Why are we creating new nodes?
    Our attack on the original image is a gradient based one, thus we need to 
    be able to produce the gradients to alter the image in the correct direction.
    Thus, gradients become a new node in our graph whose values can now be attained.
    """
    
    # From frozen graph
    image_ph = graph.get_tensor_by_name("x:0")              # input name is "x:0"
    logits_raw = graph.get_tensor_by_name("Identity:0")     # output name is "Identity:0"
    logits = tf.reshape(logits_raw, (128,))                # need to reshape because of the unnecessary dims

    # Our placeholders
    original_ph = tf.compat.v1.placeholder(tf.float32, shape=(1, 360, 360, 3), name="original")
    seed_ph = tf.compat.v1.placeholder(tf.float32, shape=(96, 128), name="seed")
    h_ph = tf.compat.v1.placeholder(tf.float32, shape=(96,), name="h")


    # Hashing pipeline
    proj = tf.reshape(tf.matmul(seed_ph, tf.reshape(logits, (128, 1))), (96,))

    """
    We want to L2 normalize the output 96D vector because the following operation is 
    the sigmoid function which is 0,1 for large negative and positive numbers, respectively.
    This means that without normalize, the hash_output node is effectively a 0,1 constant 
    function about negative and non-negative values. 
    Thus, its gradients will be 0.
    Hence, we need to normalize the valyes of proj prior to entering them into sigmoid,
    so that we don't get this 0,1 effect.
    """
    
    normalized, _ = tf.linalg.normalize(proj)

    """
    We need to use the sigmoid func in place of 
    the neg, non-neg thresholding (which is normally used to achieve hash).
    This is because the latter is not differentiable.
    """
    
    hash_output = tf.sigmoid(normalized)

    # Losses
    hash_loss = tf.reduce_mean(tf.keras.losses.binary_crossentropy(h_ph, hash_output))

    perturbation = image_ph - original_ph
    img_loss = 0.99* tf.nn.l2_loss(perturbation) + 0.01* tf.image.total_variation(perturbation)[0]

    combined_loss = 0.8*hash_loss + 0.2*img_loss

    
    # Gradients

    """
    When calculating our desired gradients we ought to differentiate the losses wrt the input,
    i.e. the image. 
    This is because we want to change our image until its respective loss is min.
    """
    
    g_hash = tf.gradients(hash_loss, image_ph)[0]
    g_img, = tf.gradients(img_loss, image_ph)
    g_combined, = tf.gradients(combined_loss, image_ph)

# %% [markdown]
# In the cell below we go about loading the input values that we will use in when we run a session on our graph. For example it's here that we specify what the target hash's bits are, so that we can input it in the feed dictionary for the key h_ph.

# %%
# === Load inputs ===
path_to_cat = "/Users/omaralmutoteh/Desktop/GitHub/neural-hash-collider/cat.png"
seed_path = "/Users/omaralmutoteh/NeuralHash/neuralhash_128x96_seed1.dat"
original_np = load_image_tf(path_to_cat)          # shape (1, 360, 360, 3)
seed_np = load_seed(seed_path)           # shape (96, 128)
h_np = hash_from_hex('59a34eabe31910abfb06f308')   # target hash's bits
x = np.copy(original_np)
best = 100  # (distance, image quality loss)
dist = 96

# %% [markdown]
# It's in the cell below where we ultimately run our attack on the cat image.

# %%
with tf.compat.v1.Session(graph=graph) as sess:
    for i in range(5000):

        """
        Our attack works as follows:
        We initially aim to just alter the image until a collison is found, 
        that is the new image's bits are the same as h_np. 
        Once that's achieved choose to minimize the difference 
        between the new image and the original cat image. 
        However this is done with the intention that the 
        changes made upon the image ensure that the difference 
        in the bits between the hash of the new image and h_np is
        at most 2
        This ensures that our image doesn't stray too far from 
        a collision.
        """


        """
        The first if's condition is achieve our current image is a collison,
        once that happens the new gradient that we apply the GD method 
        on is that of the img loss.
        This is done so that we start changing our image to minimize 
        the distance between the current image and the original 
        cat image.
        The reason this is done is because once our image is a collison
        all we care about should be to minimize image perturbation
        """
        if dist == 0:
            loss_name, loss, g = 'image', img_loss, g_img
        
        
        #The next if condition is achieved when a collision is achieved
        #in some iteration in the past (current image need not be collison).
        #If that occurs then we want to check whether our current image's
        #hash is close to the target, and we define close as being 2 bits off.
        #If it is close then we can afford to minimize both hash_loss and 
        #img_loss without being worried that our has is going to stary away too far
        #as it's already close.
        
        
        elif ((best == 0) and (dist <= 2) and (dist > 0)):
            loss_name, loss, g = 'combined', combined_loss, g_combined


        
        #The only alternative left is a collision not having been found, or that 
        #one has been found but that we've strayed far from the target bits.
        #In that case, we ask our algorithm to alter the img in the direction
        #whereby hash_loss is minimized to get our image's hash back to being 
        #close.
        
        else:
            loss_name, loss, g = 'hash', hash_loss, g_hash

        
        """
        The next if is made because by iteration 2500 I found that a collision will
        have already been found plus the img perturbation will be desirable.
        Thus, we just need to ensure that the img stays on track in terms of 
        being a collision.
        Thus, we ask our algo to minimize for hash_loss.
        """
        
        
        if i > 2500:
            loss_name, loss, g = 'hash', hash_loss, g_hash
            

        """
        As I've mentioned before, for us to run a session on our tf1 graph,
        we need to supply the session with the node values for it to complete
        a session whereby all output nodes' values can be generated.
        Thus, the following dictionary is filled to capture all of that.
        """

        feed = {
            image_ph: x,
            original_ph: original_np,
            seed_ph: seed_np,
            h_ph: h_np,     
        }


        """
        The line below is where we run our session on our graph,
        moreover in the 1st argument we specify a list of values 
        and these correspond to all the nodes' values which we want
        generated.
        """
        hash_output1, img_loss1, loss1, g1  = sess.run(
            [hash_output, img_loss, loss, g],
            feed_dict=feed
        )

        """
        In the next 3 lines we compute the dist value corresponding 
        to the current img. 
        This is simply applying <=0.5 and >0.5 thresholding on its
        hash_output, that is on the output of the sigmoid function.
        """

        binary_hash = (hash_output1 > 0.5).astype(np.float32)
        match = np.sum(binary_hash == h_np)
        dist = 96 - match

        """
        Once we have our dist, we can now check if our current
        img is a collision.
        If this happens to be the case with the number of iterations also being 
        greater than 2500 then we can break our algorithm due to the 
        aforementioned reasons.
        """

        if i > 2500 and dist == 0:

            break


        if dist < best:

            best = dist


        """
        The gradient we want to use in the GD step is the normalized 
        version of our generated gradient since I've found that 
        the gradient values tend to be small in scale (same 
        reasoning as when we used normalization to generate 
        the normalized node in the graph construction cell).
        """

        g1 /= (np.linalg.norm(g1)+ 1e-8)
        x = x - 0.6 * g1

        """
        We apply this clip step so that our img doesn't stray to 
        far from the previous img.
        """
        x = np.clip(x, 0.0, 1.0)
    
        if i%10==0:
            
            print("iteration: {}, best: {}, dist: {}, loss: {}".format(

                i, best, dist, loss_name
            ))
# Out:
# iteration: 0, best: 50, dist: 50, loss: hash
# iteration: 10, best: 40, dist: 40, loss: hash
# iteration: 20, best: 39, dist: 39, loss: hash
# iteration: 30, best: 35, dist: 35, loss: hash
# iteration: 40, best: 28, dist: 28, loss: hash
# iteration: 50, best: 25, dist: 26, loss: hash
# iteration: 60, best: 24, dist: 24, loss: hash
# iteration: 70, best: 22, dist: 24, loss: hash
# iteration: 80, best: 21, dist: 22, loss: hash
# iteration: 90, best: 19, dist: 19, loss: hash
# iteration: 100, best: 17, dist: 20, loss: hash
# iteration: 110, best: 17, dist: 17, loss: hash
# iteration: 120, best: 15, dist: 15, loss: hash
# iteration: 130, best: 13, dist: 14, loss: hash
# iteration: 140, best: 12, dist: 12, loss: hash
# iteration: 150, best: 12, dist: 13, loss: hash
# iteration: 160, best: 12, dist: 13, loss: hash
# iteration: 170, best: 12, dist: 13, loss: hash
# iteration: 180, best: 12, dist: 13, loss: hash
# iteration: 190, best: 12, dist: 12, loss: hash
# iteration: 200, best: 11, dist: 11, loss: hash
# iteration: 210, best: 11, dist: 11, loss: hash
# iteration: 220, best: 11, dist: 11, loss: hash
# iteration: 230, best: 11, dist: 11, loss: hash
# iteration: 240, best: 10, dist: 11, loss: hash
# iteration: 250, best: 9, dist: 10, loss: hash
# iteration: 260, best: 8, dist: 9, loss: hash
# iteration: 270, best: 6, dist: 6, loss: hash
# iteration: 280, best: 4, dist: 4, loss: hash
# iteration: 290, best: 3, dist: 3, loss: hash
# iteration: 300, best: 3, dist: 3, loss: hash
# iteration: 310, best: 3, dist: 3, loss: hash
# iteration: 320, best: 2, dist: 2, loss: hash
# iteration: 330, best: 1, dist: 3, loss: hash
# iteration: 340, best: 1, dist: 3, loss: hash
# iteration: 350, best: 1, dist: 2, loss: hash
# iteration: 360, best: 1, dist: 2, loss: hash
# iteration: 370, best: 1, dist: 2, loss: hash
# iteration: 380, best: 1, dist: 2, loss: hash
# iteration: 390, best: 1, dist: 2, loss: hash
# iteration: 400, best: 1, dist: 2, loss: hash
# iteration: 410, best: 1, dist: 2, loss: hash
# iteration: 420, best: 1, dist: 2, loss: hash
# iteration: 430, best: 1, dist: 2, loss: hash
# iteration: 440, best: 1, dist: 2, loss: hash
# iteration: 450, best: 1, dist: 3, loss: hash
# iteration: 460, best: 1, dist: 3, loss: hash
# iteration: 470, best: 1, dist: 3, loss: hash
# iteration: 480, best: 1, dist: 3, loss: hash
# iteration: 490, best: 1, dist: 3, loss: hash
# iteration: 500, best: 1, dist: 3, loss: hash
# iteration: 510, best: 1, dist: 2, loss: hash
# iteration: 520, best: 1, dist: 2, loss: hash
# iteration: 530, best: 1, dist: 2, loss: hash
# iteration: 540, best: 1, dist: 2, loss: hash
# iteration: 550, best: 1, dist: 3, loss: hash
# iteration: 560, best: 1, dist: 3, loss: hash
# iteration: 570, best: 1, dist: 2, loss: hash
# iteration: 580, best: 1, dist: 2, loss: hash
# iteration: 590, best: 1, dist: 2, loss: hash
# iteration: 600, best: 1, dist: 3, loss: hash
# iteration: 610, best: 1, dist: 2, loss: hash
# iteration: 620, best: 1, dist: 2, loss: hash
# iteration: 630, best: 1, dist: 2, loss: hash
# iteration: 640, best: 1, dist: 2, loss: hash
# iteration: 650, best: 1, dist: 2, loss: hash
# iteration: 660, best: 1, dist: 2, loss: hash
# iteration: 670, best: 1, dist: 2, loss: hash
# iteration: 680, best: 1, dist: 2, loss: hash
# iteration: 690, best: 1, dist: 2, loss: hash
# iteration: 700, best: 1, dist: 2, loss: hash
# iteration: 710, best: 1, dist: 2, loss: hash
# iteration: 720, best: 1, dist: 2, loss: hash
# iteration: 730, best: 1, dist: 2, loss: hash
# iteration: 740, best: 1, dist: 2, loss: hash
# iteration: 750, best: 1, dist: 1, loss: hash
# iteration: 760, best: 1, dist: 2, loss: hash
# iteration: 770, best: 1, dist: 2, loss: hash
# iteration: 780, best: 1, dist: 1, loss: hash
# iteration: 790, best: 1, dist: 2, loss: hash
# iteration: 800, best: 1, dist: 2, loss: hash
# iteration: 810, best: 1, dist: 2, loss: hash
# iteration: 820, best: 1, dist: 2, loss: hash
# iteration: 830, best: 1, dist: 2, loss: hash
# iteration: 840, best: 1, dist: 2, loss: hash
# iteration: 850, best: 1, dist: 2, loss: hash
# iteration: 860, best: 1, dist: 2, loss: hash
# iteration: 870, best: 1, dist: 2, loss: hash
# iteration: 880, best: 1, dist: 2, loss: hash
# iteration: 890, best: 1, dist: 2, loss: hash
# iteration: 900, best: 1, dist: 2, loss: hash
# iteration: 910, best: 1, dist: 1, loss: hash
# iteration: 920, best: 1, dist: 2, loss: hash
# iteration: 930, best: 1, dist: 2, loss: hash
# iteration: 940, best: 1, dist: 1, loss: hash
# iteration: 950, best: 0, dist: 0, loss: hash
# iteration: 960, best: 0, dist: 1, loss: combined
# iteration: 970, best: 0, dist: 3, loss: hash
# iteration: 980, best: 0, dist: 3, loss: hash
# iteration: 990, best: 0, dist: 3, loss: combined
# iteration: 1000, best: 0, dist: 3, loss: hash
# iteration: 1010, best: 0, dist: 2, loss: hash
# iteration: 1020, best: 0, dist: 3, loss: hash
# iteration: 1030, best: 0, dist: 2, loss: combined
# iteration: 1040, best: 0, dist: 2, loss: hash
# iteration: 1050, best: 0, dist: 2, loss: combined
# iteration: 1060, best: 0, dist: 2, loss: hash
# iteration: 1070, best: 0, dist: 4, loss: hash
# iteration: 1080, best: 0, dist: 4, loss: hash
# iteration: 1090, best: 0, dist: 3, loss: hash
# iteration: 1100, best: 0, dist: 2, loss: hash
# iteration: 1110, best: 0, dist: 3, loss: combined
# iteration: 1120, best: 0, dist: 2, loss: hash
# iteration: 1130, best: 0, dist: 2, loss: combined
# iteration: 1140, best: 0, dist: 4, loss: combined
# iteration: 1150, best: 0, dist: 2, loss: hash
# iteration: 1160, best: 0, dist: 3, loss: combined
# iteration: 1170, best: 0, dist: 4, loss: combined
# iteration: 1180, best: 0, dist: 3, loss: combined
# iteration: 1190, best: 0, dist: 3, loss: hash
# iteration: 1200, best: 0, dist: 2, loss: combined
# iteration: 1210, best: 0, dist: 4, loss: hash
# iteration: 1220, best: 0, dist: 2, loss: hash
# iteration: 1230, best: 0, dist: 2, loss: hash
# iteration: 1240, best: 0, dist: 3, loss: combined
# iteration: 1250, best: 0, dist: 3, loss: combined
# iteration: 1260, best: 0, dist: 3, loss: combined
# iteration: 1270, best: 0, dist: 3, loss: hash
# iteration: 1280, best: 0, dist: 3, loss: hash
# iteration: 1290, best: 0, dist: 2, loss: hash
# iteration: 1300, best: 0, dist: 4, loss: combined
# iteration: 1310, best: 0, dist: 4, loss: hash
# iteration: 1320, best: 0, dist: 4, loss: combined
# iteration: 1330, best: 0, dist: 3, loss: hash
# iteration: 1340, best: 0, dist: 3, loss: hash
# iteration: 1350, best: 0, dist: 2, loss: hash
# iteration: 1360, best: 0, dist: 4, loss: hash
# iteration: 1370, best: 0, dist: 4, loss: combined
# iteration: 1380, best: 0, dist: 2, loss: hash
# iteration: 1390, best: 0, dist: 3, loss: hash
# iteration: 1400, best: 0, dist: 3, loss: hash
# iteration: 1410, best: 0, dist: 4, loss: hash
# iteration: 1420, best: 0, dist: 2, loss: hash
# iteration: 1430, best: 0, dist: 3, loss: combined
# iteration: 1440, best: 0, dist: 2, loss: hash
# iteration: 1450, best: 0, dist: 2, loss: hash
# iteration: 1460, best: 0, dist: 3, loss: combined
# iteration: 1470, best: 0, dist: 3, loss: hash
# iteration: 1480, best: 0, dist: 4, loss: hash
# iteration: 1490, best: 0, dist: 3, loss: hash
# iteration: 1500, best: 0, dist: 2, loss: combined
# iteration: 1510, best: 0, dist: 3, loss: hash
# iteration: 1520, best: 0, dist: 4, loss: hash
# iteration: 1530, best: 0, dist: 2, loss: hash
# iteration: 1540, best: 0, dist: 3, loss: hash
# iteration: 1550, best: 0, dist: 3, loss: hash
# iteration: 1560, best: 0, dist: 3, loss: hash
# iteration: 1570, best: 0, dist: 3, loss: hash
# iteration: 1580, best: 0, dist: 3, loss: hash
# iteration: 1590, best: 0, dist: 3, loss: hash
# iteration: 1600, best: 0, dist: 3, loss: hash
# iteration: 1610, best: 0, dist: 4, loss: hash
# iteration: 1620, best: 0, dist: 3, loss: hash
# iteration: 1630, best: 0, dist: 4, loss: hash
# iteration: 1640, best: 0, dist: 4, loss: combined
# iteration: 1650, best: 0, dist: 4, loss: hash
# iteration: 1660, best: 0, dist: 2, loss: hash
# iteration: 1670, best: 0, dist: 3, loss: combined
# iteration: 1680, best: 0, dist: 3, loss: hash
# iteration: 1690, best: 0, dist: 4, loss: combined
# iteration: 1700, best: 0, dist: 2, loss: hash
# iteration: 1710, best: 0, dist: 2, loss: hash
# iteration: 1720, best: 0, dist: 3, loss: hash
# iteration: 1730, best: 0, dist: 3, loss: hash
# iteration: 1740, best: 0, dist: 3, loss: hash
# iteration: 1750, best: 0, dist: 3, loss: combined
# iteration: 1760, best: 0, dist: 3, loss: hash
# iteration: 1770, best: 0, dist: 2, loss: hash
# iteration: 1780, best: 0, dist: 2, loss: combined
# iteration: 1790, best: 0, dist: 3, loss: combined
# iteration: 1800, best: 0, dist: 3, loss: hash
# iteration: 1810, best: 0, dist: 4, loss: hash
# iteration: 1820, best: 0, dist: 4, loss: combined
# iteration: 1830, best: 0, dist: 3, loss: hash
# iteration: 1840, best: 0, dist: 3, loss: hash
# iteration: 1850, best: 0, dist: 2, loss: combined
# iteration: 1860, best: 0, dist: 2, loss: hash
# iteration: 1870, best: 0, dist: 4, loss: combined
# iteration: 1880, best: 0, dist: 4, loss: hash
# iteration: 1890, best: 0, dist: 5, loss: hash
# iteration: 1900, best: 0, dist: 2, loss: combined
# iteration: 1910, best: 0, dist: 3, loss: hash
# iteration: 1920, best: 0, dist: 3, loss: hash
# iteration: 1930, best: 0, dist: 3, loss: combined
# iteration: 1940, best: 0, dist: 4, loss: hash
# iteration: 1950, best: 0, dist: 3, loss: hash
# iteration: 1960, best: 0, dist: 4, loss: hash
# iteration: 1970, best: 0, dist: 2, loss: hash
# iteration: 1980, best: 0, dist: 3, loss: combined
# iteration: 1990, best: 0, dist: 2, loss: hash
# iteration: 2000, best: 0, dist: 2, loss: hash
# iteration: 2010, best: 0, dist: 3, loss: combined
# iteration: 2020, best: 0, dist: 4, loss: hash
# iteration: 2030, best: 0, dist: 4, loss: combined
# iteration: 2040, best: 0, dist: 2, loss: hash
# iteration: 2050, best: 0, dist: 2, loss: combined
# iteration: 2060, best: 0, dist: 2, loss: combined
# iteration: 2070, best: 0, dist: 3, loss: hash
# iteration: 2080, best: 0, dist: 4, loss: hash
# iteration: 2090, best: 0, dist: 4, loss: hash
# iteration: 2100, best: 0, dist: 4, loss: hash
# iteration: 2110, best: 0, dist: 4, loss: hash
# iteration: 2120, best: 0, dist: 3, loss: hash
# iteration: 2130, best: 0, dist: 4, loss: combined
# iteration: 2140, best: 0, dist: 3, loss: combined
# iteration: 2150, best: 0, dist: 3, loss: combined
# iteration: 2160, best: 0, dist: 2, loss: combined
# iteration: 2170, best: 0, dist: 2, loss: hash
# iteration: 2180, best: 0, dist: 3, loss: combined
# iteration: 2190, best: 0, dist: 2, loss: hash
# iteration: 2200, best: 0, dist: 3, loss: combined
# iteration: 2210, best: 0, dist: 4, loss: hash
# iteration: 2220, best: 0, dist: 3, loss: combined
# iteration: 2230, best: 0, dist: 2, loss: hash
# iteration: 2240, best: 0, dist: 3, loss: hash
# iteration: 2250, best: 0, dist: 2, loss: combined
# iteration: 2260, best: 0, dist: 4, loss: hash
# iteration: 2270, best: 0, dist: 3, loss: hash
# iteration: 2280, best: 0, dist: 4, loss: combined
# iteration: 2290, best: 0, dist: 2, loss: hash
# iteration: 2300, best: 0, dist: 3, loss: hash
# iteration: 2310, best: 0, dist: 3, loss: hash
# iteration: 2320, best: 0, dist: 4, loss: hash
# iteration: 2330, best: 0, dist: 4, loss: hash
# iteration: 2340, best: 0, dist: 4, loss: hash
# iteration: 2350, best: 0, dist: 2, loss: combined
# iteration: 2360, best: 0, dist: 3, loss: hash
# iteration: 2370, best: 0, dist: 2, loss: combined
# iteration: 2380, best: 0, dist: 4, loss: hash
# iteration: 2390, best: 0, dist: 4, loss: combined
# iteration: 2400, best: 0, dist: 3, loss: combined
# iteration: 2410, best: 0, dist: 2, loss: hash
# iteration: 2420, best: 0, dist: 3, loss: hash
# iteration: 2430, best: 0, dist: 2, loss: combined
# iteration: 2440, best: 0, dist: 3, loss: combined
# iteration: 2450, best: 0, dist: 3, loss: hash
# iteration: 2460, best: 0, dist: 5, loss: hash
# iteration: 2470, best: 0, dist: 3, loss: hash
# iteration: 2480, best: 0, dist: 2, loss: combined
# iteration: 2490, best: 0, dist: 3, loss: hash
# iteration: 2500, best: 0, dist: 4, loss: hash
# iteration: 2510, best: 0, dist: 2, loss: hash
# iteration: 2520, best: 0, dist: 2, loss: hash
# iteration: 2530, best: 0, dist: 3, loss: hash
# iteration: 2540, best: 0, dist: 3, loss: hash
# iteration: 2550, best: 0, dist: 2, loss: hash
# iteration: 2560, best: 0, dist: 2, loss: hash
# iteration: 2570, best: 0, dist: 2, loss: hash
# iteration: 2580, best: 0, dist: 2, loss: hash
# iteration: 2590, best: 0, dist: 2, loss: hash
# iteration: 2600, best: 0, dist: 3, loss: hash
# iteration: 2610, best: 0, dist: 2, loss: hash
# iteration: 2620, best: 0, dist: 2, loss: hash
# iteration: 2630, best: 0, dist: 2, loss: hash
# iteration: 2640, best: 0, dist: 1, loss: hash
# iteration: 2650, best: 0, dist: 1, loss: hash
# iteration: 2660, best: 0, dist: 1, loss: hash
# iteration: 2670, best: 0, dist: 1, loss: hash
# iteration: 2680, best: 0, dist: 1, loss: hash
# iteration: 2690, best: 0, dist: 1, loss: hash
# iteration: 2700, best: 0, dist: 1, loss: hash

# %%
save_image(x, os.path.join('.', "cat_attack.png"))
